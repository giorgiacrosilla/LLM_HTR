# %%
import os
from torchmetrics.text import CharErrorRate, EditDistance, WordErrorRate

def read_file(file_path):
    with open(file_path, 'r', encoding='utf-8') as f:
        return f.read().strip()

def evaluate_transcriptions(pred_folder, target_folder, file_limit=529):
    cer = CharErrorRate()
    wer = WordErrorRate()
    edit_distance = EditDistance()

    total_cer = 0
    total_wer = 0
    total_edit_distance = 0
    file_count = 0

    for filename in sorted(os.listdir(pred_folder))[:file_limit]:
        if filename.endswith('.txt'):
            pred_path = os.path.join(pred_folder, filename)
            target_path = os.path.join(target_folder, filename)

            if os.path.exists(target_path):
                pred_text = read_file(pred_path)
                target_text = read_file(target_path)

                file_cer = cer([pred_text], [target_text])
                file_wer = wer([pred_text], [target_text])
                file_edit_distance = edit_distance([pred_text], [target_text])

                total_cer += file_cer
                total_wer += file_wer
                total_edit_distance += file_edit_distance
                file_count += 1

                print(f"File {file_count}: {filename}")
                print(f"WER: {file_wer:.4f}")
                print(f"CER: {file_cer:.4f}")
                print(f"Edit Distance: {file_edit_distance:.4f}")
                print("--------------------")

            if file_count >= file_limit:
                break

    if file_count > 0:
        avg_cer = total_cer / file_count
        avg_wer = total_wer / file_count
        avg_edit_distance = total_edit_distance / file_count

        print("\nOverall Results:")
        print(f"Average WER: {avg_wer:.4f}")
        print(f"Average CER: {avg_cer:.4f}")
        print(f"Average Edit Distance: {avg_edit_distance:.4f}")
        print(f"Total files processed: {file_count}")
    else:
        print("No matching files found.")

# Example usage
pred_folder = 'transcriptions_IAM_pixtral'
target_folder = 'IAM/txt'
evaluate_transcriptions(pred_folder, target_folder)
# Out:
# File 1: c04-156.txt
# WER: 0.1224
# CER: 0.0688
# Edit Distance: 19.0000
# --------------------
# File 2: c04-160.txt
# WER: 0.0800
# CER: 0.0619
# Edit Distance: 27.0000
# --------------------
# File 3: c06-083.txt
# WER: 0.2000
# CER: 0.1480
# Edit Distance: 70.0000
# --------------------
# File 4: d01-024.txt
# WER: 0.0820
# CER: 0.1185
# Edit Distance: 98.0000
# --------------------
# File 5: d01-056.txt
# WER: 0.0822
# CER: 0.0425
# Edit Distance: 17.0000
# --------------------
# File 6: d01-060.txt
# WER: 0.3750
# CER: 0.3405
# Edit Distance: 379.0000
# --------------------
# File 7: d03-112.txt
# WER: 0.4918
# CER: 0.5373
# Edit Distance: 269.0000
# --------------------
# File 8: d04-005.txt
# WER: 0.1833
# CER: 0.1308
# Edit Distance: 45.0000
# --------------------
# File 9: d04-008.txt
# WER: 0.0741
# CER: 0.1070
# Edit Distance: 40.0000
# --------------------
# File 10: d04-071.txt
# WER: 0.1356
# CER: 0.0874
# Edit Distance: 27.0000
# --------------------
# File 11: d04-075.txt
# WER: 0.7132
# CER: 0.6735
# Edit Distance: 559.0000
# --------------------
# File 12: d04-081.txt
# WER: 0.1091
# CER: 0.0440
# Edit Distance: 14.0000
# --------------------
# File 13: d04-117.txt
# WER: 0.1538
# CER: 0.0898
# Edit Distance: 36.0000
# --------------------
# File 14: d04-121.txt
# WER: 0.1250
# CER: 0.0941
# Edit Distance: 38.0000
# --------------------
# File 15: d06-000.txt
# WER: 0.2165
# CER: 0.2045
# Edit Distance: 273.0000
# --------------------
# File 16: d06-015.txt
# WER: 0.0175
# CER: 0.0139
# Edit Distance: 4.0000
# --------------------
# File 17: d06-030.txt
# WER: 0.0182
# CER: 0.0161
# Edit Distance: 5.0000
# --------------------
# File 18: d06-050.txt
# WER: 0.1000
# CER: 0.0759
# Edit Distance: 29.0000
# --------------------
# File 19: d06-082.txt
# WER: 0.0690
# CER: 0.0507
# Edit Distance: 15.0000
# --------------------
# File 20: d06-091.txt
# WER: 0.0476
# CER: 0.0664
# Edit Distance: 29.0000
# --------------------
# File 21: e01-014.txt
# WER: 0.0667
# CER: 0.1004
# Edit Distance: 28.0000
# --------------------
# File 22: e01-018.txt
# WER: 0.0870
# CER: 0.0831
# Edit Distance: 33.0000
# --------------------
# File 23: e06-006.txt
# WER: 0.0000
# CER: 0.0102
# Edit Distance: 4.0000
# --------------------
# File 24: e06-037.txt
# WER: 1.0278
# CER: 0.9953
# Edit Distance: 571.0000
# --------------------
# File 25: e06-041.txt
# WER: 0.0469
# CER: 0.0246
# Edit Distance: 9.0000
# --------------------
# File 26: f04-046.txt
# WER: 1.0000
# CER: 1.0152
# Edit Distance: 430.0000
# --------------------
# File 27: f04-049.txt
# WER: 0.0000
# CER: 0.0097
# Edit Distance: 4.0000
# --------------------
# File 28: f04-093.txt
# WER: 0.0588
# CER: 0.0735
# Edit Distance: 28.0000
# --------------------
# File 29: f04-096.txt
# WER: 0.0000
# CER: 0.0115
# Edit Distance: 6.0000
# --------------------
# File 30: f04-100.txt
# WER: 0.0357
# CER: 0.0186
# Edit Distance: 9.0000
# --------------------
# File 31: f07-028b.txt
# WER: 0.0247
# CER: 0.0306
# Edit Distance: 15.0000
# --------------------
# File 32: f07-032b.txt
# WER: 0.0976
# CER: 0.0313
# Edit Distance: 16.0000
# --------------------
# File 33: f07-036.txt
# WER: 0.0175
# CER: 0.0179
# Edit Distance: 6.0000
# --------------------
# File 34: f07-039b.txt
# WER: 1.0000
# CER: 1.0170
# Edit Distance: 472.0000
# --------------------
# File 35: f07-042b.txt
# WER: 0.0179
# CER: 0.0130
# Edit Distance: 4.0000
# --------------------
# File 36: f07-046b.txt
# WER: 1.0137
# CER: 1.0348
# Edit Distance: 547.0000
# --------------------
# File 37: g01-083.txt
# WER: 1.0619
# CER: 1.0706
# Edit Distance: 893.0000
# --------------------
# File 38: g03-016.txt
# WER: 1.0448
# CER: 1.0865
# Edit Distance: 509.0000
# --------------------
# File 39: g03-058.txt
# WER: 0.0000
# CER: 0.0117
# Edit Distance: 4.0000
# --------------------
# File 40: g04-036.txt
# WER: 0.1081
# CER: 0.1010
# Edit Distance: 100.0000
# --------------------
# File 41: g04-039.txt
# WER: 1.0411
# CER: 1.0916
# Edit Distance: 550.0000
# --------------------
# File 42: g04-055.txt
# WER: 1.0274
# CER: 1.0593
# Edit Distance: 568.0000
# --------------------
# File 43: g04-060.txt
# WER: 0.0000
# CER: 0.0109
# Edit Distance: 4.0000
# --------------------
# File 44: g04-063.txt
# WER: 1.0102
# CER: 1.0257
# Edit Distance: 699.0000
# --------------------
# File 45: h01-004.txt
# WER: 1.0517
# CER: 1.0776
# Edit Distance: 433.0000
# --------------------
# File 46: m01-090.txt
# WER: 1.1111
# CER: 1.1855
# Edit Distance: 592.0000
# --------------------
# File 47: m01-115.txt
# WER: 0.0161
# CER: 0.0269
# Edit Distance: 9.0000
# --------------------
# File 48: m01-160.txt
# WER: 1.0213
# CER: 1.0178
# Edit Distance: 369.0000
# --------------------
# File 49: m02-052.txt
# WER: 1.0517
# CER: 1.0636
# Edit Distance: 445.0000
# --------------------
# File 50: m02-075.txt
# WER: 1.0000
# CER: 1.0144
# Edit Distance: 367.0000
# --------------------
# File 51: m02-083.txt
# WER: 1.0345
# CER: 1.0243
# Edit Distance: 942.0000
# --------------------
# File 52: m02-090.txt
# WER: 1.0660
# CER: 1.0406
# Edit Distance: 803.0000
# --------------------
# File 53: m02-102.txt
# WER: 1.0441
# CER: 1.0607
# Edit Distance: 586.0000
# --------------------
# File 54: m02-106.txt
# WER: 1.0488
# CER: 1.0636
# Edit Distance: 715.0000
# --------------------
# File 55: m03-062.txt
# WER: 0.1000
# CER: 0.0744
# Edit Distance: 25.0000
# --------------------
# File 56: m03-095.txt
# WER: 0.0377
# CER: 0.0264
# Edit Distance: 8.0000
# --------------------
# File 57: m04-000.txt
# WER: 1.0526
# CER: 1.0613
# Edit Distance: 419.0000
# --------------------
# File 58: m04-007.txt
# WER: 1.0000
# CER: 1.0127
# Edit Distance: 550.0000
# --------------------
# File 59: m04-012.txt
# WER: 0.0455
# CER: 0.0265
# Edit Distance: 10.0000
# --------------------
# File 60: m04-019.txt
# WER: 1.2143
# CER: 1.0145
# Edit Distance: 430.0000
# --------------------
# File 61: m04-024.txt
# WER: 1.0690
# CER: 1.0585
# Edit Distance: 443.0000
# --------------------
# File 62: m04-145.txt
# WER: 0.1000
# CER: 0.0867
# Edit Distance: 34.0000
# --------------------
# File 63: m04-152.txt
# WER: 0.1754
# CER: 0.1201
# Edit Distance: 49.0000
# --------------------
# File 64: m04-164.txt
# WER: 1.2308
# CER: 1.0212
# Edit Distance: 540.0000
# --------------------
# File 65: m04-180.txt
# WER: 0.0938
# CER: 0.0936
# Edit Distance: 38.0000
# --------------------
# File 66: m04-190.txt
# WER: 1.0769
# CER: 1.0308
# Edit Distance: 675.0000
# --------------------
# File 67: m04-200.txt
# WER: 0.1552
# CER: 0.1516
# Edit Distance: 52.0000
# --------------------
# File 68: m04-209.txt
# WER: 0.0385
# CER: 0.0374
# Edit Distance: 11.0000
# --------------------
# File 69: m04-216.txt
# WER: 1.0370
# CER: 1.0526
# Edit Distance: 375.0000
# --------------------
# File 70: m04-222.txt
# WER: 0.2679
# CER: 0.2134
# Edit Distance: 86.0000
# --------------------
# File 71: m04-251.txt
# WER: 1.3125
# CER: 1.1238
# Edit Distance: 125.0000
# --------------------
# File 72: m06-019.txt
# WER: 0.0952
# CER: 0.0994
# Edit Distance: 33.0000
# --------------------
# File 73: n02-000.txt
# WER: 1.1719
# CER: 1.1072
# Edit Distance: 482.0000
# --------------------
# File 74: n02-016.txt
# WER: 1.0986
# CER: 1.0339
# Edit Distance: 552.0000
# --------------------
# File 75: n02-082a.txt
# WER: 1.2182
# CER: 1.0494
# Edit Distance: 427.0000
# --------------------
# File 76: n02-098.txt
# WER: 1.1667
# CER: 1.0377
# Edit Distance: 391.0000
# --------------------
# File 77: n03-079.txt
# WER: 1.0392
# CER: 0.9781
# Edit Distance: 329.0000
# --------------------
# File 78: n03-082.txt
# WER: 0.2105
# CER: 0.2438
# Edit Distance: 131.0000
# --------------------
# File 79: n03-091.txt
# WER: 1.0132
# CER: 1.0104
# Edit Distance: 506.0000
# --------------------
# File 80: n04-015.txt
# WER: 1.1324
# CER: 1.0130
# Edit Distance: 484.0000
# --------------------
# File 81: n04-022.txt
# WER: 0.0938
# CER: 0.1108
# Edit Distance: 43.0000
# --------------------
# File 82: n04-031.txt
# WER: 1.1148
# CER: 1.0171
# Edit Distance: 450.0000
# --------------------
# File 83: n04-039.txt
# WER: 0.1739
# CER: 0.1939
# Edit Distance: 101.0000
# --------------------
# File 84: n04-044.txt
# WER: 0.0460
# CER: 0.0407
# Edit Distance: 20.0000
# --------------------
# File 85: n04-171.txt
# WER: 0.1786
# CER: 0.1760
# Edit Distance: 60.0000
# --------------------
# File 86: n04-183.txt
# WER: 1.2037
# CER: 0.9830
# Edit Distance: 423.0000
# --------------------
# File 87: n04-190.txt
# WER: 1.0545
# CER: 1.0308
# Edit Distance: 396.0000
# --------------------
# File 88: n04-195.txt
# WER: 0.1455
# CER: 0.1359
# Edit Distance: 42.0000
# --------------------
# File 89: n06-148.txt
# WER: 1.1507
# CER: 1.0364
# Edit Distance: 534.0000
# --------------------
# File 90: n06-156.txt
# WER: 0.0781
# CER: 0.1295
# Edit Distance: 111.0000
# --------------------
# File 91: n06-163.txt
# WER: 0.1646
# CER: 0.0989
# Edit Distance: 44.0000
# --------------------
# File 92: n06-169.txt
# WER: 0.1324
# CER: 0.1387
# Edit Distance: 53.0000
# --------------------
# File 93: n06-175.txt
# WER: 0.2273
# CER: 0.2096
# Edit Distance: 105.0000
# --------------------
# File 94: n06-182.txt
# WER: 1.1250
# CER: 1.0667
# Edit Distance: 453.0000
# --------------------
# File 95: n06-186.txt
# WER: 1.1333
# CER: 0.9920
# Edit Distance: 487.0000
# --------------------
# File 96: n06-194.txt
# WER: 0.1719
# CER: 0.0924
# Edit Distance: 33.0000
# --------------------
# File 97: n06-201.txt
# WER: 1.1940
# CER: 1.0640
# Edit Distance: 448.0000
# --------------------
# File 98: p02-017.txt
# WER: 0.0345
# CER: 0.0472
# Edit Distance: 15.0000
# --------------------
# File 99: p02-121.txt
# WER: 0.1887
# CER: 0.2049
# Edit Distance: 103.0000
# --------------------
# File 100: p02-127.txt
# WER: 1.0303
# CER: 1.0588
# Edit Distance: 469.0000
# --------------------
# File 101: p02-131.txt
# WER: 1.0145
# CER: 0.9971
# Edit Distance: 443.0000
# --------------------
# File 102: p02-155.txt
# WER: 1.2222
# CER: 1.0172
# Edit Distance: 59.0000
# --------------------
# File 103: p03-004.txt
# WER: 1.0625
# CER: 1.0799
# Edit Distance: 486.0000
# --------------------
# File 104: p03-009.txt
# WER: 0.0690
# CER: 0.0778
# Edit Distance: 27.0000
# --------------------
# File 105: p03-057.txt
# WER: 0.3115
# CER: 0.2857
# Edit Distance: 156.0000
# --------------------
# File 106: p03-069.txt
# WER: 1.0411
# CER: 0.9776
# Edit Distance: 519.0000
# --------------------
# File 107: p03-087.txt
# WER: 0.1316
# CER: 0.1478
# Edit Distance: 68.0000
# --------------------
# File 108: p03-096.txt
# WER: 0.2000
# CER: 0.1816
# Edit Distance: 75.0000
# --------------------
# File 109: p03-103.txt
# WER: 0.2549
# CER: 0.2342
# Edit Distance: 103.0000
# --------------------
# File 110: p03-112.txt
# WER: 0.0833
# CER: 0.0838
# Edit Distance: 32.0000
# --------------------
# File 111: p03-121.txt
# WER: 1.1935
# CER: 0.9859
# Edit Distance: 459.0000
# --------------------
# File 112: p03-135.txt
# WER: 1.1905
# CER: 1.1078
# Edit Distance: 489.0000
# --------------------
# File 113: p03-142.txt
# WER: 0.0702
# CER: 0.0733
# Edit Distance: 25.0000
# --------------------
# File 114: p03-151.txt
# WER: 0.1852
# CER: 0.1328
# Edit Distance: 47.0000
# --------------------
# File 115: p03-158.txt
# WER: 0.0896
# CER: 0.0914
# Edit Distance: 34.0000
# --------------------
# File 116: p03-185.txt
# WER: 0.0750
# CER: 0.0511
# Edit Distance: 24.0000
# --------------------
#
# Overall Results:
# Average WER: 0.5139
# Average CER: 0.4881
# Average Edit Distance: 236.2414
# Total files processed: 116

# %%
import os
import numpy as np

def levenshtein_distance(s1: str, s2: str) -> int:
    """Calculates the Levenshtein distance between two strings."""
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

def cer_single(prediction: str, ground_truth: str) -> float:
    """Calculates the Character Error Rate (CER) between two strings."""
    # Calculate the Levenshtein distance (edit distance)
    edit_distance = levenshtein_distance(prediction, ground_truth)

    # CER = edit distance / number of characters in the ground truth
    return edit_distance / len(ground_truth) if len(ground_truth) > 0 else 0

def calculate_cer_over_dataset(predictions_folder: str, ground_truth_folder: str) -> float:
    """Calculates the average CER over a dataset of transcriptions."""
    cer_scores = []

    # Ensure both folders exist
    if not os.path.exists(predictions_folder) or not os.path.exists(ground_truth_folder):
        raise ValueError("Predictions or Ground Truth folder does not exist.")

    # List of files in both folders (assuming .txt files)
    prediction_files = [f for f in os.listdir(predictions_folder) if f.endswith('.txt')]
    ground_truth_files = [f for f in os.listdir(ground_truth_folder) if f.endswith('.txt')]

    # Ensure both folders contain the same files
    common_files = set(prediction_files).intersection(set(ground_truth_files))

    for file_name in common_files:
        pred_file_path = os.path.join(predictions_folder, file_name)
        gt_file_path = os.path.join(ground_truth_folder, file_name)

        # Read the predicted and ground truth transcriptions
        with open(pred_file_path, 'r', encoding='utf-8') as pred_file:
            prediction_text = pred_file.read().strip()

        with open(gt_file_path, 'r', encoding='utf-8') as gt_file:
            ground_truth_text = gt_file.read().strip()

        # Calculate CER for the current pair and convert it to percentage
        cer = cer_single(prediction_text, ground_truth_text) * 100
        cer_scores.append(cer)

        print(f"{file_name} - CER: {cer:.2f}%")

    # Return the average CER across the dataset as percentage
    return np.mean(cer_scores)

# Example usage
predictions_folder = "transcriptions_IAM_claude"  # Path to the folder containing predicted transcriptions
ground_truth_folder = "IAM/aachen_validation_txt"  # Path to the folder containing ground truth transcriptions

average_cer = calculate_cer_over_dataset(predictions_folder, ground_truth_folder)
print(f"Average CER over the dataset: {average_cer:.2f}%")
# Out:
# c06-083.txt - CER: 3.17%
# p03-142.txt - CER: 6.45%
# f04-100.txt - CER: 19.25%
# d01-060.txt - CER: 32.43%
# n03-082.txt - CER: 8.65%
# p03-103.txt - CER: 8.81%
# e01-018.txt - CER: 6.80%
# d04-005.txt - CER: 2.99%
# m04-145.txt - CER: 4.03%
# m04-251.txt - CER: 9.47%
# m02-083.txt - CER: 2.58%
# n04-039.txt - CER: 5.04%
# d06-050.txt - CER: 2.62%
# d04-117.txt - CER: 4.99%
# m04-209.txt - CER: 3.06%
# p03-057.txt - CER: 9.32%
# g04-039.txt - CER: 8.40%
# m03-095.txt - CER: 3.96%
# m03-062.txt - CER: 4.46%
# p02-131.txt - CER: 2.64%
# g01-083.txt - CER: 7.06%
# d04-121.txt - CER: 4.43%
# d04-008.txt - CER: 2.68%
# p03-069.txt - CER: 4.19%
# f04-049.txt - CER: 2.90%
# p02-127.txt - CER: 5.88%
# n06-156.txt - CER: 2.75%
# m04-152.txt - CER: 4.29%
# m04-200.txt - CER: 3.60%
# n06-163.txt - CER: 5.98%
# n02-098.txt - CER: 7.29%
# m02-052.txt - CER: 6.06%
# d06-015.txt - CER: 2.79%
# n04-195.txt - CER: 2.82%
# e06-006.txt - CER: 3.56%
# f07-028b.txt - CER: 1.22%
# n04-183.txt - CER: 2.97%
# f04-046.txt - CER: 2.42%
# g03-058.txt - CER: 4.08%
# g04-036.txt - CER: 7.64%
# m04-019.txt - CER: 5.90%
# d06-000.txt - CER: 21.90%
# f07-032b.txt - CER: 2.74%
# m01-090.txt - CER: 7.02%
# p03-121.txt - CER: 2.73%
# d01-056.txt - CER: 1.75%
# p03-009.txt - CER: 11.62%
# e01-014.txt - CER: 6.45%
# n06-194.txt - CER: 8.68%
# m01-160.txt - CER: 7.83%
# n06-182.txt - CER: 2.09%
# m04-012.txt - CER: 5.03%
# m04-164.txt - CER: 8.80%
# m04-007.txt - CER: 5.32%
# d03-112.txt - CER: 39.44%
# p02-017.txt - CER: 2.60%
# p02-155.txt - CER: 27.08%
# m02-102.txt - CER: 7.48%
# n02-016.txt - CER: 2.80%
# f07-042b.txt - CER: 3.25%
# n04-190.txt - CER: 3.08%
# n03-079.txt - CER: 5.68%
# g03-016.txt - CER: 5.95%
# f04-096.txt - CER: 29.69%
# f07-039b.txt - CER: 3.40%
# d06-082.txt - CER: 2.03%
# n06-169.txt - CER: 4.55%
# m02-090.txt - CER: 3.53%
# m04-000.txt - CER: 5.81%
# d04-071.txt - CER: 3.24%
# p03-087.txt - CER: 7.56%
# n06-148.txt - CER: 2.07%
# p03-096.txt - CER: 8.38%
# f04-093.txt - CER: 3.05%
# n04-044.txt - CER: 5.30%
# d06-091.txt - CER: 6.41%
# m04-180.txt - CER: 4.20%
# p03-151.txt - CER: 2.82%
# d04-081.txt - CER: 3.46%
# m04-190.txt - CER: 5.66%
# p03-158.txt - CER: 4.32%
# m02-075.txt - CER: 3.60%
# m04-216.txt - CER: 4.91%
# n02-082a.txt - CER: 9.54%
# d06-030.txt - CER: 2.58%
# m04-024.txt - CER: 5.08%
# p03-112.txt - CER: 8.64%
# n06-186.txt - CER: 9.01%
# d04-075.txt - CER: 44.85%
# f07-046b.txt - CER: 3.48%
# p02-121.txt - CER: 5.49%
# g04-055.txt - CER: 3.95%
# n06-175.txt - CER: 3.34%
# f07-036.txt - CER: 2.69%
# m06-019.txt - CER: 2.71%
# m02-106.txt - CER: 7.16%
# h01-004.txt - CER: 8.70%
# n04-015.txt - CER: 3.33%
# n04-171.txt - CER: 2.36%
# p03-185.txt - CER: 5.32%
# m04-222.txt - CER: 4.08%
# n04-031.txt - CER: 3.03%
# n04-022.txt - CER: 2.99%
# n03-091.txt - CER: 5.79%
# c04-160.txt - CER: 3.76%
# g04-060.txt - CER: 2.72%
# e06-041.txt - CER: 3.01%
# p03-135.txt - CER: 10.54%
# n06-201.txt - CER: 2.16%
# e06-037.txt - CER: 3.81%
# c04-156.txt - CER: 3.38%
# g04-063.txt - CER: 4.36%
# p03-004.txt - CER: 10.47%
# n02-000.txt - CER: 7.25%
# d01-024.txt - CER: 7.51%
# m01-115.txt - CER: 1.21%
# Average CER over the dataset: 6.44%

# %%
import os
import numpy as np

def levenshtein_distance(s1: list, s2: list) -> int:
    """Calculates the Levenshtein distance between two lists of words."""
    if len(s1) < len(s2):
        return levenshtein_distance(s2, s1)

    # len(s1) >= len(s2)
    if len(s2) == 0:
        return len(s1)

    previous_row = list(range(len(s2) + 1))
    for i, word1 in enumerate(s1):
        current_row = [i + 1]
        for j, word2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1
            substitutions = previous_row[j] + (word1 != word2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

def wer_single(prediction: str, ground_truth: str) -> float:
    """Calculates the Word Error Rate (WER) between two strings."""
    # Split the strings into words
    prediction_words = prediction.split()
    ground_truth_words = ground_truth.split()

    # Calculate the Levenshtein distance (edit distance) for words
    edit_distance = levenshtein_distance(prediction_words, ground_truth_words)

    # WER = edit distance / number of words in the ground truth
    return edit_distance / len(ground_truth_words) if len(ground_truth_words) > 0 else 0

def calculate_wer_over_dataset(predictions_folder: str, ground_truth_folder: str) -> float:
    """Calculates the average WER over a dataset of transcriptions."""
    wer_scores = []

    # Ensure both folders exist
    if not os.path.exists(predictions_folder) or not os.path.exists(ground_truth_folder):
        raise ValueError("Predictions or Ground Truth folder does not exist.")

    # List of files in both folders (assuming .txt files)
    prediction_files = [f for f in os.listdir(predictions_folder) if f.endswith('.txt')]
    ground_truth_files = [f for f in os.listdir(ground_truth_folder) if f.endswith('.txt')]

    # Ensure both folders contain the same files
    common_files = set(prediction_files).intersection(set(ground_truth_files))

    for file_name in common_files:
        pred_file_path = os.path.join(predictions_folder, file_name)
        gt_file_path = os.path.join(ground_truth_folder, file_name)

        # Read the predicted and ground truth transcriptions
        with open(pred_file_path, 'r', encoding='utf-8') as pred_file:
            prediction_text = pred_file.read().strip()

        with open(gt_file_path, 'r', encoding='utf-8') as gt_file:
            ground_truth_text = gt_file.read().strip()

        # Calculate WER for the current pair and convert it to percentage
        wer = wer_single(prediction_text, ground_truth_text) * 100
        wer_scores.append(wer)

        print(f"{file_name} - WER: {wer:.2f}%")

    # Return the average WER across the dataset as percentage
    return np.mean(wer_scores)

# Example usage
predictions_folder = "transcriptions_IAM_claude"  # Path to the folder containing predicted transcriptions
ground_truth_folder = "IAM/aachen_validation_txt"  # Path to the folder containing ground truth transcriptions

average_wer = calculate_wer_over_dataset(predictions_folder, ground_truth_folder)
print(f"Average WER over the dataset: {average_wer:.2f}%")
# Out:
# c06-083.txt - WER: 5.33%
# p03-142.txt - WER: 5.26%
# f04-100.txt - WER: 17.86%
# d01-060.txt - WER: 31.25%
# n03-082.txt - WER: 7.02%
# p03-103.txt - WER: 7.84%
# e01-018.txt - WER: 5.80%
# d04-005.txt - WER: 1.67%
# m04-145.txt - WER: 3.33%
# m04-251.txt - WER: 6.25%
# m02-083.txt - WER: 2.59%
# n04-039.txt - WER: 2.17%
# d06-050.txt - WER: 0.00%
# d04-117.txt - WER: 3.08%
# m04-209.txt - WER: 0.00%
# p03-057.txt - WER: 3.28%
# g04-039.txt - WER: 8.22%
# m03-095.txt - WER: 3.77%
# m03-062.txt - WER: 5.00%
# p02-131.txt - WER: 0.00%
# g01-083.txt - WER: 7.08%
# d04-121.txt - WER: 3.12%
# d04-008.txt - WER: 0.00%
# p03-069.txt - WER: 0.00%
# f04-049.txt - WER: 3.80%
# p02-127.txt - WER: 1.52%
# n06-156.txt - WER: 3.12%
# m04-152.txt - WER: 10.53%
# m04-200.txt - WER: 3.45%
# n06-163.txt - WER: 3.80%
# n02-098.txt - WER: 3.70%
# m02-052.txt - WER: 3.45%
# d06-015.txt - WER: 0.00%
# n04-195.txt - WER: 0.00%
# e06-006.txt - WER: 0.00%
# f07-028b.txt - WER: 0.00%
# n04-183.txt - WER: 0.00%
# f04-046.txt - WER: 0.00%
# g03-058.txt - WER: 6.90%
# g04-036.txt - WER: 8.11%
# m04-019.txt - WER: 1.79%
# d06-000.txt - WER: 21.65%
# f07-032b.txt - WER: 7.32%
# m01-090.txt - WER: 4.17%
# p03-121.txt - WER: 3.23%
# d01-056.txt - WER: 2.74%
# p03-009.txt - WER: 12.07%
# e01-014.txt - WER: 3.33%
# n06-194.txt - WER: 6.25%
# m01-160.txt - WER: 6.38%
# n06-182.txt - WER: 1.56%
# m04-012.txt - WER: 1.52%
# m04-164.txt - WER: 10.77%
# m04-007.txt - WER: 4.48%
# d03-112.txt - WER: 27.87%
# p02-017.txt - WER: 0.00%
# p02-155.txt - WER: 22.22%
# m02-102.txt - WER: 7.35%
# n02-016.txt - WER: 0.00%
# f07-042b.txt - WER: 0.00%
# n04-190.txt - WER: 1.82%
# n03-079.txt - WER: 15.69%
# g03-016.txt - WER: 2.99%
# f04-096.txt - WER: 26.88%
# f07-039b.txt - WER: 0.00%
# d06-082.txt - WER: 0.00%
# n06-169.txt - WER: 0.00%
# m02-090.txt - WER: 4.72%
# m04-000.txt - WER: 1.75%
# d04-071.txt - WER: 6.78%
# p03-087.txt - WER: 5.26%
# n06-148.txt - WER: 0.00%
# p03-096.txt - WER: 3.08%
# f04-093.txt - WER: 0.00%
# n04-044.txt - WER: 4.60%
# d06-091.txt - WER: 2.38%
# m04-180.txt - WER: 0.00%
# p03-151.txt - WER: 12.96%
# d04-081.txt - WER: 7.27%
# m04-190.txt - WER: 6.41%
# p03-158.txt - WER: 10.45%
# m02-075.txt - WER: 0.00%
# m04-216.txt - WER: 3.70%
# n02-082a.txt - WER: 5.45%
# d06-030.txt - WER: 0.00%
# m04-024.txt - WER: 1.72%
# p03-112.txt - WER: 9.72%
# n06-186.txt - WER: 3.33%
# d04-075.txt - WER: 45.59%
# f07-046b.txt - WER: 2.74%
# p02-121.txt - WER: 9.43%
# g04-055.txt - WER: 4.11%
# n06-175.txt - WER: 0.00%
# f07-036.txt - WER: 0.00%
# m06-019.txt - WER: 0.00%
# m02-106.txt - WER: 6.10%
# h01-004.txt - WER: 5.17%
# n04-015.txt - WER: 1.47%
# n04-171.txt - WER: 0.00%
# p03-185.txt - WER: 6.25%
# m04-222.txt - WER: 1.79%
# n04-031.txt - WER: 0.00%
# n04-022.txt - WER: 3.12%
# n03-091.txt - WER: 1.32%
# c04-160.txt - WER: 5.33%
# g04-060.txt - WER: 0.00%
# e06-041.txt - WER: 0.00%
# p03-135.txt - WER: 3.17%
# n06-201.txt - WER: 1.49%
# e06-037.txt - WER: 1.39%
# c04-156.txt - WER: 8.16%
# g04-063.txt - WER: 1.02%
# p03-004.txt - WER: 14.06%
# n02-000.txt - WER: 4.69%
# d01-024.txt - WER: 4.92%
# m01-115.txt - WER: 1.61%
# Average WER over the dataset: 5.11%
