# %%
import os
from bs4 import BeautifulSoup

# assign directories
gt_folder = 'BGdataset/filtered100html'
pred_folder = 'transcriptionsBG_gpt4/html'

# Function to find tags with positions in an HTML file
def find_tags_with_positions(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    body = soup.body

    if not body:
        return []

    results = []
    body_str = str(body)

    for tag in body.find_all(['b', 'u', 'i', 's']):
        tag_str = str(tag)

        # Find opening tag
        opening_tag = f"<{tag.name}"
        closing_tag = f"</{tag.name}>"

        # Get positions of opening and closing tags
        opening_pos = body_str.index(tag_str)
        closing_pos = opening_pos + len(tag_str) - len(closing_tag)

        # Extract text content
        text_content = tag.get_text(strip=True)

        results.append({
            'tag': tag.name,
            'opening_position': opening_pos,
            'closing_position': closing_pos,
            'content': text_content
        })

    return results

# Function to compare two lists of tags
def compare_tag_lists(predicted, ground_truth):
    total_tags = len(predicted)
    print(f"Total predicted tags: {total_tags}")

    correct_tags = 0
    correct_positions = 0
    correct_content = 0
    perfect_matches = 0
    mismatches = []

    for i, (pred, gt) in enumerate(zip(predicted, ground_truth)):
        # Step 1: Check if the tags match
        if pred['tag'] == gt['tag']:
            correct_tags += 1

            # Step 2: Check if both the opening and closing positions match
            if pred['opening_position'] == gt['opening_position'] and pred['closing_position'] == gt['closing_position']:
                correct_positions += 1

                # Step 3: Check if the content matches after confirming tag and position match
                if pred['content'] == gt['content']:
                    correct_content += 1
                    perfect_matches += 1
                    print(f"Tag {i}: Perfect match (tag, positions, and content)")
                else:
                    print(f"Tag {i}: Tag and positions match, but content differs")
            else:
                print(f"Tag {i}: Tag matches, but positions differ")
        else:
            # Log mismatches
            mismatches.append(i)
            print(f"Tag {i}: Tag mismatch")

            # Check if any other fields match in case of tag mismatch
            if pred['opening_position'] == gt['opening_position']:
                print(f"Tag {i}: Opening position matches despite tag mismatch")
            if pred['closing_position'] == gt['closing_position']:
                print(f"Tag {i}: Closing position matches despite tag mismatch")
            if pred['content'] == gt['content']:
                print(f"Tag {i}: Content matches despite tag mismatch")

    # Summary of the results
    print(f"\nSummary:")
    print(f"Correct tags: {correct_tags} out of {total_tags}")
    print(f"Correct positions: {correct_positions} out of {total_tags}")
    print(f"Correct content: {correct_content} out of {total_tags}")
    print(f"Perfect matches: {perfect_matches} out of {total_tags}")

    if mismatches:
        print(f"Mismatched tags at indices: {mismatches}")

# iterate over files in the ground truth folder
for gt_filename in os.listdir(gt_folder):
    gt_filepath = os.path.join(gt_folder, gt_filename)

    # open and read the ground truth file
    with open(gt_filepath, 'r', encoding='utf-8') as gt_file:
        gt_content = gt_file.read()

    # iterate over files in the predicted folder
    for pred_filename in os.listdir(pred_folder):
        pred_filepath = os.path.join(pred_folder, pred_filename)

        # check if the file names match (without extensions)
        if os.path.splitext(gt_filename)[0] == os.path.splitext(pred_filename)[0]:
            # open and read the predicted file
            with open(pred_filepath, 'r', encoding='utf-8') as pred_file:
                pred_content = pred_file.read()

            # Find tags and positions in both ground truth and predicted content
            listtags_gt = find_tags_with_positions(gt_content)
            listtags_predicted = find_tags_with_positions(pred_content)

            # Compare the tag lists
            compare_tag_lists(listtags_predicted, listtags_gt)
# Out:
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 10
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
# Tag 4: Tag mismatch
# Tag 5: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 10
# Correct positions: 0 out of 10
# Correct content: 0 out of 10
# Perfect matches: 0 out of 10
# Mismatched tags at indices: [0, 1, 4]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [2]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 0: Content matches despite tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Total predicted tags: 5
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 1
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 8
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
# Tag 3: Tag matches, but positions differ
# Tag 4: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 8
# Correct positions: 0 out of 8
# Correct content: 0 out of 8
# Perfect matches: 0 out of 8
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 7
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 7
# Correct positions: 0 out of 7
# Correct content: 0 out of 7
# Perfect matches: 0 out of 7
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 2
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 11
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
# Tag 4: Tag matches, but positions differ
# Tag 5: Tag matches, but positions differ
# Tag 6: Tag mismatch
#
# Summary:
# Correct tags: 4 out of 11
# Correct positions: 0 out of 11
# Correct content: 0 out of 11
# Perfect matches: 0 out of 11
# Mismatched tags at indices: [0, 3, 6]
# Total predicted tags: 4
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 0: Content matches despite tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 5
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [1, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 1, 3]
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
# Tag 4: Tag mismatch
# Tag 5: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 1, 3, 4, 5]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2, 3]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 5
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2, 3]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 5
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Mismatched tags at indices: [0, 1, 3]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 5
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Total predicted tags: 8
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
# Tag 4: Tag mismatch
# Tag 5: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 8
# Correct positions: 0 out of 8
# Correct content: 0 out of 8
# Perfect matches: 0 out of 8
# Mismatched tags at indices: [0, 1, 2, 3, 4]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 5
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1]
# Total predicted tags: 9
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 9
# Correct positions: 0 out of 9
# Correct content: 0 out of 9
# Perfect matches: 0 out of 9
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 6
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 2 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 3]
# Total predicted tags: 5
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
# Tag 4: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Mismatched tags at indices: [0, 3]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 12
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
# Tag 4: Tag matches, but positions differ
# Tag 5: Tag mismatch
# Tag 6: Tag mismatch
# Tag 7: Tag mismatch
# Tag 8: Tag matches, but positions differ
# Tag 9: Tag matches, but positions differ
# Tag 10: Tag matches, but positions differ
# Tag 11: Tag matches, but positions differ
#
# Summary:
# Correct tags: 8 out of 12
# Correct positions: 0 out of 12
# Correct content: 0 out of 12
# Perfect matches: 0 out of 12
# Mismatched tags at indices: [0, 5, 6, 7]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 5
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 10
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 10
# Correct positions: 0 out of 10
# Correct content: 0 out of 10
# Perfect matches: 0 out of 10
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 8
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 8
# Correct positions: 0 out of 8
# Correct content: 0 out of 8
# Perfect matches: 0 out of 8
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0]
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
# Tag 4: Tag mismatch
# Tag 5: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 1, 2, 3, 4, 5]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1]
# Total predicted tags: 7
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
# Tag 4: Tag mismatch
# Tag 5: Tag matches, but positions differ
# Tag 6: Tag mismatch
#
# Summary:
# Correct tags: 3 out of 7
# Correct positions: 0 out of 7
# Correct content: 0 out of 7
# Perfect matches: 0 out of 7
# Mismatched tags at indices: [0, 1, 4, 6]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2, 3]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 4
# Tag 0: Perfect match (tag, positions, and content)
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 4
# Correct positions: 1 out of 4
# Correct content: 1 out of 4
# Perfect matches: 1 out of 4
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
#
# Summary:
# Correct tags: 4 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 28
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 28
# Correct positions: 0 out of 28
# Correct content: 0 out of 28
# Perfect matches: 0 out of 28
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 11
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
# Tag 4: Tag mismatch
# Tag 5: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 11
# Correct positions: 0 out of 11
# Correct content: 0 out of 11
# Perfect matches: 0 out of 11
# Mismatched tags at indices: [0, 2, 3, 4, 5]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [1, 2, 3]
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 13
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 13
# Correct positions: 0 out of 13
# Correct content: 0 out of 13
# Perfect matches: 0 out of 13
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 9
#
# Summary:
# Correct tags: 0 out of 9
# Correct positions: 0 out of 9
# Correct content: 0 out of 9
# Perfect matches: 0 out of 9
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 4
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 2
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 5
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
# Tag 4: Tag matches, but positions differ
#
# Summary:
# Correct tags: 5 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# ...
# Tag 4: Tag mismatch
# Tag 5: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 2, 4]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 0: Content matches despite tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0]
# Total predicted tags: 8
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
# Tag 4: Tag mismatch
# Tag 5: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 8
# Correct positions: 0 out of 8
# Correct content: 0 out of 8
# Perfect matches: 0 out of 8
# Mismatched tags at indices: [0, 2, 3, 4]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
# Tag 4: Tag matches, but positions differ
# Tag 5: Tag matches, but positions differ
#
# Summary:
# Correct tags: 4 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 3]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 2 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [1, 3]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 7
# Tag 0: Tag mismatch
# Tag 0: Closing position matches despite tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 7
# Correct positions: 0 out of 7
# Correct content: 0 out of 7
# Perfect matches: 0 out of 7
# Mismatched tags at indices: [0, 1, 3]
# Total predicted tags: 2
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1, 2]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 3
#
# Summary:
# Correct tags: 0 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Total predicted tags: 8
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 8
# Correct positions: 0 out of 8
# Correct content: 0 out of 8
# Perfect matches: 0 out of 8
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 5
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
# Tag 4: Tag matches, but positions differ
#
# Summary:
# Correct tags: 3 out of 5
# Correct positions: 0 out of 5
# Correct content: 0 out of 5
# Perfect matches: 0 out of 5
# Mismatched tags at indices: [2, 3]
# Total predicted tags: 12
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag matches, but positions differ
# Tag 4: Tag mismatch
# Tag 5: Tag mismatch
# Tag 6: Tag matches, but positions differ
# Tag 7: Tag mismatch
# Tag 8: Tag mismatch
#
# Summary:
# Correct tags: 3 out of 12
# Correct positions: 0 out of 12
# Correct content: 0 out of 12
# Perfect matches: 0 out of 12
# Mismatched tags at indices: [1, 2, 4, 5, 7, 8]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 8
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag mismatch
# Tag 3: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 8
# Correct positions: 0 out of 8
# Correct content: 0 out of 8
# Perfect matches: 0 out of 8
# Mismatched tags at indices: [0, 2]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 4
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Mismatched tags at indices: [0, 1, 2, 3]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 6
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
# Tag 3: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 6
# Correct positions: 0 out of 6
# Correct content: 0 out of 6
# Perfect matches: 0 out of 6
# Mismatched tags at indices: [0, 1, 2]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 4
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
# Tag 3: Tag matches, but positions differ
#
# Summary:
# Correct tags: 4 out of 4
# Correct positions: 0 out of 4
# Correct content: 0 out of 4
# Perfect matches: 0 out of 4
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [1]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1, 2]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
# Tag 2: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1, 2]
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag matches, but positions differ
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 1 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 2
# Tag 0: Tag mismatch
# Tag 1: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0, 1]
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 1
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Mismatched tags at indices: [0]
# Total predicted tags: 1
# Tag 0: Tag matches, but positions differ
#
# Summary:
# Correct tags: 1 out of 1
# Correct positions: 0 out of 1
# Correct content: 0 out of 1
# Perfect matches: 0 out of 1
# Total predicted tags: 0
#
# Summary:
# Correct tags: 0 out of 0
# Correct positions: 0 out of 0
# Correct content: 0 out of 0
# Perfect matches: 0 out of 0
# Total predicted tags: 2
# Tag 0: Tag mismatch
#
# Summary:
# Correct tags: 0 out of 2
# Correct positions: 0 out of 2
# Correct content: 0 out of 2
# Perfect matches: 0 out of 2
# Mismatched tags at indices: [0]
# Total predicted tags: 3
# Tag 0: Tag mismatch
# Tag 1: Tag matches, but positions differ
# Tag 2: Tag matches, but positions differ
#
# Summary:
# Correct tags: 2 out of 3
# Correct positions: 0 out of 3
# Correct content: 0 out of 3
# Perfect matches: 0 out of 3
# Mismatched tags at indices: [0]

# %%
import os
from bs4 import BeautifulSoup
from collections import defaultdict

# assign directories
gt_folder = 'BGdataset/filtered100html'
pred_folder = 'transcriptions_BG_internVL/html'

def find_tags_with_positions(html_content):
    soup = BeautifulSoup(html_content, 'html.parser')
    body = soup.body
    if not body:
        return []

    results = []
    body_str = str(body)

    for tag in body.find_all(['b', 'u', 'i', 's']):
        tag_str = str(tag)
        opening_pos = body_str.index(tag_str)
        closing_pos = opening_pos + len(tag_str) - len(f"</{tag.name}>")
        text_content = tag.get_text(strip=True)

        results.append({
            'tag': tag.name,
            'opening_position': opening_pos,
            'closing_position': closing_pos,
            'content': text_content
        })
    print(results)

    return results

def compare_tag_lists(predicted, ground_truth):
    metrics = defaultdict(int)
    metrics['total_tags'] = len(predicted)

    for pred, gt in zip(predicted, ground_truth):
        if pred['tag'] == gt['tag']:
            metrics['correct_tags'] += 1
            if pred['opening_position'] == gt['opening_position'] and pred['closing_position'] == gt['closing_position']:
                metrics['correct_positions'] += 1
                if pred['content'] == gt['content']:
                    metrics['correct_content'] += 1
                    metrics['perfect_matches'] += 1
    print(metrics)
    return metrics

def process_files(gt_folder, pred_folder):
    total_metrics = defaultdict(int)

    for gt_filename in os.listdir(gt_folder):
        gt_basename = os.path.splitext(gt_filename)[0]
        gt_filepath = os.path.join(gt_folder, gt_filename)
        pred_filepath = os.path.join(pred_folder, f"{gt_basename}.html")

        if not os.path.exists(pred_filepath):
            print(f"Warning: No matching predicted file for {gt_filename}")
            continue

        with open(gt_filepath, 'r', encoding='utf-8') as gt_file, open(pred_filepath, 'r', encoding='utf-8') as pred_file:
            gt_content = gt_file.read()
            pred_content = pred_file.read()

        listtags_gt = find_tags_with_positions(gt_content)
        listtags_predicted = find_tags_with_positions(pred_content)

        file_metrics = compare_tag_lists(listtags_predicted, listtags_gt)

        for key, value in file_metrics.items():
            total_metrics[key] += value

    return total_metrics

def calculate_percentages(metrics):
    total_tags = metrics['total_tags']
    if total_tags == 0:
        return {k: 0 for k in metrics}

    return {
        'correct_tags': (metrics['correct_tags'] / total_tags) * 100,
        'correct_positions': (metrics['correct_positions'] / total_tags) * 100,
        'correct_content': (metrics['correct_content'] / total_tags) * 100,
        'perfect_matches': (metrics['perfect_matches'] / total_tags) * 100
    }

def main():
    total_metrics = process_files(gt_folder, pred_folder)
    percentages = calculate_percentages(total_metrics)

    print(f"\nRisultati finali su tutti i file processati:")
    print(f"Totale tag processati: {total_metrics['total_tags']}")
    print(f"Percentuale di tag correttamente riconosciuti: {percentages['correct_tags']:.2f}%")
    print(f"Percentuale di posizioni corrette: {percentages['correct_positions']:.2f}%")
    print(f"Percentuale di contenuti corrispondenti: {percentages['correct_content']:.2f}%")
    print(f"Percentuale di corrispondenze perfette (tag, contenuto e posizione): {percentages['perfect_matches']:.2f}%")

if __name__ == "__main__":
    main()
# Out:
# [{'tag': 'u', 'opening_position': 92, 'closing_position': 99, 'content': 'real'}, {'tag': 'u', 'opening_position': 182, 'closing_position': 191, 'content': 'almost'}, {'tag': 'u', 'opening_position': 271, 'closing_position': 284, 'content': 'dreadfully'}]
# [{'tag': 'b', 'opening_position': 51, 'closing_position': 55, 'content': '/'}, {'tag': 'u', 'opening_position': 71, 'closing_position': 84, 'content': 'how I feel'}, {'tag': 's', 'opening_position': 102, 'closing_position': 262, 'content': "Sister confessed hateMy dear sweet dearly I'm not happy — thanmorehere —that'sthe reason of my love — Jai a gore from a very true"}, {'tag': 'i', 'opening_position': 197, 'closing_position': 206, 'content': "that's"}, {'tag': 'u', 'opening_position': 305, 'closing_position': 319, 'content': 'Mr. Dickens'}, {'tag': 'b', 'opening_position': 359, 'closing_position': 377, 'content': 'Sherlock Holmes'}]
# defaultdict(<class 'int'>, {'total_tags': 6, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 28, 'closing_position': 37, 'content': 'should'}, {'tag': 'u', 'opening_position': 98, 'closing_position': 108, 'content': 'started'}, {'tag': 'u', 'opening_position': 225, 'closing_position': 230, 'content': 'it'}, {'tag': 'u', 'opening_position': 276, 'closing_position': 281, 'content': 'me'}, {'tag': 'u', 'opening_position': 308, 'closing_position': 315, 'content': 'when'}]
# [{'tag': 'u', 'opening_position': 397, 'closing_position': 410, 'content': 'Maikel mo,'}, {'tag': 'i', 'opening_position': 414, 'closing_position': 425, 'content': 'All do -'}]
# defaultdict(<class 'int'>, {'total_tags': 2, 'correct_tags': 1})
# [{'tag': 'i', 'opening_position': 12, 'closing_position': 49, 'content': 'newspaper clipping pasted on sheet'}, {'tag': 'u', 'opening_position': 818, 'closing_position': 824, 'content': 'you'}]
# [{'tag': 'b', 'opening_position': 45, 'closing_position': 56, 'content': 'March 8.'}, {'tag': 'b', 'opening_position': 107, 'closing_position': 131, 'content': 'THE TURN OF THE ROAD.'}, {'tag': 'b', 'opening_position': 176, 'closing_position': 184, 'content': 'Coff,'}, {'tag': 'b', 'opening_position': 984, 'closing_position': 1019, 'content': 'Oh, for a line from the outside!'}]
# defaultdict(<class 'int'>, {'total_tags': 4})
# [{'tag': 'u', 'opening_position': 23, 'closing_position': 38, 'content': 'the day that'}, {'tag': 'u', 'opening_position': 158, 'closing_position': 166, 'content': 'years'}, {'tag': 'u', 'opening_position': 342, 'closing_position': 348, 'content': 'not'}, {'tag': 'u', 'opening_position': 371, 'closing_position': 377, 'content': 'and'}, {'tag': 'u', 'opening_position': 382, 'closing_position': 390, 'content': 'break'}, {'tag': 'u', 'opening_position': 395, 'closing_position': 402, 'content': 'them'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 327, 'closing_position': 333, 'content': 'not'}, {'tag': 'u', 'opening_position': 399, 'closing_position': 406, 'content': 'real'}, {'tag': 'u', 'opening_position': 462, 'closing_position': 469, 'content': 'dear'}, {'tag': 'u', 'opening_position': 478, 'closing_position': 485, 'content': 'very'}]
# [{'tag': 'i', 'opening_position': 39, 'closing_position': 57, 'content': 'trading avenue'}, {'tag': 'u', 'opening_position': 63, 'closing_position': 67, 'content': 'I'}, {'tag': 'i', 'opening_position': 79, 'closing_position': 89, 'content': 'her mrs'}, {'tag': 'i', 'opening_position': 125, 'closing_position': 147, 'content': 'are her "carc a hot'}, {'tag': 'i', 'opening_position': 223, 'closing_position': 238, 'content': 'silly bugger'}, {'tag': 'i', 'opening_position': 256, 'closing_position': 277, 'content': 'his father of Miss'}, {'tag': 'i', 'opening_position': 381, 'closing_position': 405, 'content': 'mirs ah stong turfier'}, {'tag': 'b', 'opening_position': 434, 'closing_position': 439, 'content': 'if'}, {'tag': 'i', 'opening_position': 561, 'closing_position': 587, 'content': 'feels ab mous moment iu'}]
# defaultdict(<class 'int'>, {'total_tags': 9, 'correct_tags': 1})
# [{'tag': 's', 'opening_position': 500, 'closing_position': 507, 'content': 'been'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 359, 'closing_position': 365, 'content': 'who'}, {'tag': 'u', 'opening_position': 403, 'closing_position': 410, 'content': 'sure'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 22, 'content': 'you see.'}, {'tag': 'u', 'opening_position': 55, 'closing_position': 59, 'content': 'V'}, {'tag': 'i', 'opening_position': 71, 'closing_position': 77, 'content': "I'm"}, {'tag': 'b', 'opening_position': 111, 'closing_position': 124, 'content': 'Mamma Vier'}, {'tag': 'i', 'opening_position': 710, 'closing_position': 718, 'content': 'Yours'}]
# defaultdict(<class 'int'>, {'total_tags': 5, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 57, 'closing_position': 64, 'content': 'must'}, {'tag': 'u', 'opening_position': 106, 'closing_position': 113, 'content': 'dear'}, {'tag': 'u', 'opening_position': 240, 'closing_position': 246, 'content': 'all'}, {'tag': 'u', 'opening_position': 282, 'closing_position': 289, 'content': 'know'}, {'tag': 's', 'opening_position': 401, 'closing_position': 412, 'content': 'St. Paul'}, {'tag': 's', 'opening_position': 460, 'closing_position': 465, 'content': 'th'}]
# [{'tag': 'u', 'opening_position': 233, 'closing_position': 240, 'content': 'Long'}, {'tag': 'i', 'opening_position': 475, 'closing_position': 481, 'content': 'and'}, {'tag': 'b', 'opening_position': 499, 'closing_position': 503, 'content': 'r'}, {'tag': 'u', 'opening_position': 507, 'closing_position': 511, 'content': 'r'}]
# defaultdict(<class 'int'>, {'total_tags': 4, 'correct_tags': 2})
# [{'tag': 's', 'opening_position': 16, 'closing_position': 30, 'content': 'convictions'}, {'tag': 'u', 'opening_position': 390, 'closing_position': 398, 'content': 'Belle'}, {'tag': 'u', 'opening_position': 413, 'closing_position': 419, 'content': 'P.S'}, {'tag': 's', 'opening_position': 475, 'closing_position': 485, 'content': 'written'}]
# [{'tag': 'i', 'opening_position': 136, 'closing_position': 156, 'content': 'Dear Mrs. Patrick'}]
# defaultdict(<class 'int'>, {'total_tags': 1})
# [{'tag': 'u', 'opening_position': 35, 'closing_position': 44, 'content': 'Friday'}, {'tag': 'u', 'opening_position': 582, 'closing_position': 592, 'content': 'nothing'}, {'tag': 'u', 'opening_position': 649, 'closing_position': 656, 'content': 'have'}]
# [{'tag': 'u', 'opening_position': 81, 'closing_position': 92, 'content': 'Fall – r'}]
# defaultdict(<class 'int'>, {'total_tags': 1, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 26, 'closing_position': 31, 'content': 'is'}, {'tag': 'u', 'opening_position': 209, 'closing_position': 217, 'content': 'hoped'}, {'tag': 'u', 'opening_position': 540, 'closing_position': 547, 'content': 'rest'}, {'tag': 'u', 'opening_position': 640, 'closing_position': 651, 'content': 'palpably'}, {'tag': 'u', 'opening_position': 742, 'closing_position': 750, 'content': 'can’t'}]
# [{'tag': 'i', 'opening_position': 423, 'closing_position': 434, 'content': 'go of me'}, {'tag': 'u', 'opening_position': 443, 'closing_position': 448, 'content': 'me'}, {'tag': 'i', 'opening_position': 456, 'closing_position': 467, 'content': 'tomorrow'}, {'tag': 'u', 'opening_position': 504, 'closing_position': 515, 'content': 'Tomorrow'}, {'tag': 'b', 'opening_position': 581, 'closing_position': 592, 'content': 'tomorrow'}]
# defaultdict(<class 'int'>, {'total_tags': 5, 'correct_tags': 2})
# [{'tag': 'u', 'opening_position': 183, 'closing_position': 192, 'content': 'Sunday'}]
# [{'tag': 'b', 'opening_position': 40, 'closing_position': 50, 'content': "Jimmy's"}, {'tag': 'b', 'opening_position': 59, 'closing_position': 65, 'content': 'Dee'}, {'tag': 'b', 'opening_position': 215, 'closing_position': 224, 'content': 'Bernie'}, {'tag': 'u', 'opening_position': 282, 'closing_position': 303, 'content': 'Dinner on Thursday'}]
# defaultdict(<class 'int'>, {'total_tags': 4})
# [{'tag': 'u', 'opening_position': 53, 'closing_position': 64, 'content': 'terribly'}, {'tag': 'u', 'opening_position': 654, 'closing_position': 661, 'content': 'sure'}, {'tag': 'u', 'opening_position': 812, 'closing_position': 823, 'content': 'splendid'}, {'tag': 'u', 'opening_position': 841, 'closing_position': 854, 'content': 'positively'}]
# [{'tag': 'i', 'opening_position': 71, 'closing_position': 98, 'content': 'are â © Bed oir ter rely'}, {'tag': 'b', 'opening_position': 370, 'closing_position': 375, 'content': 'It'}, {'tag': 'i', 'opening_position': 379, 'closing_position': 389, 'content': 'met ime'}, {'tag': 'i', 'opening_position': 407, 'closing_position': 417, 'content': 'Hue she'}, {'tag': 'u', 'opening_position': 510, 'closing_position': 515, 'content': 'it'}, {'tag': 'b', 'opening_position': 617, 'closing_position': 624, 'content': 'lues'}, {'tag': 'i', 'opening_position': 628, 'closing_position': 634, 'content': 'Fue'}, {'tag': 'b', 'opening_position': 638, 'closing_position': 643, 'content': 'el'}, {'tag': 'u', 'opening_position': 753, 'closing_position': 758, 'content': 'If'}, {'tag': 'b', 'opening_position': 806, 'closing_position': 816, 'content': 'It here'}, {'tag': 'i', 'opening_position': 820, 'closing_position': 825, 'content': 'I'}, {'tag': 'b', 'opening_position': 829, 'closing_position': 835, 'content': 'luc'}, {'tag': 'u', 'opening_position': 1067, 'closing_position': 1072, 'content': 'It'}, {'tag': 'b', 'opening_position': 1076, 'closing_position': 1081, 'content': 'al'}, {'tag': 'b', 'opening_position': 1147, 'closing_position': 1153, 'content': 'One'}, {'tag': 'i', 'opening_position': 1374, 'closing_position': 1379, 'content': 'It'}, {'tag': 'u', 'opening_position': 1412, 'closing_position': 1417, 'content': 'Me'}]
# defaultdict(<class 'int'>, {'total_tags': 17})
# [{'tag': 'u', 'opening_position': 34, 'closing_position': 44, 'content': 'Mar. 24'}]
# [{'tag': 'b', 'opening_position': 110, 'closing_position': 130, 'content': 'Monday sigurs - 8'}]
# defaultdict(<class 'int'>, {'total_tags': 1})
# [{'tag': 'u', 'opening_position': 132, 'closing_position': 138, 'content': 'are'}]
# [{'tag': 'i', 'opening_position': 16, 'closing_position': 104, 'content': 'And we are both delighted to hearI am before he was picked --'}, {'tag': 'u', 'opening_position': 19, 'closing_position': 55, 'content': 'And we are both delighted to hear'}, {'tag': 'i', 'opening_position': 116, 'closing_position': 186, 'content': 'If we all my wakinghours (and his face been'}, {'tag': 'u', 'opening_position': 119, 'closing_position': 141, 'content': 'If we all my waking'}, {'tag': 'u', 'opening_position': 198, 'closing_position': 225, 'content': 'abse my body was waking)'}, {'tag': 'i', 'opening_position': 237, 'closing_position': 282, 'content': 'To add upon my thoughtsDesires may'}, {'tag': 'u', 'opening_position': 240, 'closing_position': 266, 'content': 'To add upon my thoughts'}, {'tag': 'u', 'opening_position': 294, 'closing_position': 324, 'content': 'be forced & deciding --'}, {'tag': 'i', 'opening_position': 336, 'closing_position': 384, 'content': 'All avilationsare forced and dying --'}, {'tag': 'u', 'opening_position': 339, 'closing_position': 356, 'content': 'All avilations'}, {'tag': 'u', 'opening_position': 396, 'closing_position': 425, 'content': 'And he let the triple life'}, {'tag': 'u', 'opening_position': 437, 'closing_position': 464, 'content': 'for his dope -- a hutler'}, {'tag': 'i', 'opening_position': 476, 'closing_position': 509, 'content': 'Life is an union I miss'}, {'tag': 'u', 'opening_position': 479, 'closing_position': 505, 'content': 'Life is an union I miss'}, {'tag': 'u', 'opening_position': 521, 'closing_position': 540, 'content': 'Hence why I pray'}, {'tag': 'u', 'opening_position': 552, 'closing_position': 589, 'content': 'to see you lay a hew & hear me'}, {'tag': 'i', 'opening_position': 601, 'closing_position': 662, 'content': 'of my love for you & myhope --'}, {'tag': 'u', 'opening_position': 604, 'closing_position': 634, 'content': 'of my love for you & my'}, {'tag': 'i', 'opening_position': 674, 'closing_position': 705, 'content': 'and my dear mother --'}, {'tag': 'u', 'opening_position': 677, 'closing_position': 701, 'content': 'and my dear mother --'}, {'tag': 'u', 'opening_position': 717, 'closing_position': 750, 'content': 'when you tell me your eyes you'}, {'tag': 'u', 'opening_position': 762, 'closing_position': 788, 'content': 'dear & dear only --'}]
# defaultdict(<class 'int'>, {'total_tags': 22})
# [{'tag': 'u', 'opening_position': 235, 'closing_position': 241, 'content': 'are'}]
# [{'tag': 'u', 'opening_position': 144, 'closing_position': 150, 'content': 'a -'}, {'tag': 'i', 'opening_position': 180, 'closing_position': 292, 'content': 'Bleadlhane - me -Hn -plefowHoi - ple - dea'}, {'tag': 'u', 'opening_position': 236, 'closing_position': 242, 'content': 'ple'}, {'tag': 'u', 'opening_position': 475, 'closing_position': 480, 'content': 'ya'}, {'tag': 'i', 'opening_position': 494, 'closing_position': 621, 'content': 'Lute - I luaby gm.teer -drea- Plea - HimdoufpleIrusThe'}, {'tag': 'u', 'opening_position': 534, 'closing_position': 541, 'content': 'drea'}, {'tag': 'u', 'opening_position': 236, 'closing_position': 242, 'content': 'ple'}]
# defaultdict(<class 'int'>, {'total_tags': 7, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 198, 'closing_position': 210, 'content': 'Therefore'}, {'tag': 'u', 'opening_position': 215, 'closing_position': 227, 'content': 'telephone'}]
# [{'tag': 'u', 'opening_position': 33, 'closing_position': 46, 'content': "2 o' Clock"}, {'tag': 'b', 'opening_position': 87, 'closing_position': 94, 'content': 'mail'}, {'tag': 'i', 'opening_position': 101, 'closing_position': 106, 'content': 'If'}, {'tag': 'i', 'opening_position': 171, 'closing_position': 180, 'content': 'Yours'}]
# defaultdict(<class 'int'>, {'total_tags': 4, 'correct_tags': 1})
# []
# [{'tag': 'u', 'opening_position': 10, 'closing_position': 27, 'content': 'You languishes'}, {'tag': 'u', 'opening_position': 88, 'closing_position': 147, 'content': 'Mind to meet me next day Saturday to bring home, I hope.'}, {'tag': 'u', 'opening_position': 166, 'closing_position': 188, 'content': 'on Friday April 1st'}, {'tag': 'u', 'opening_position': 263, 'closing_position': 279, 'content': 'to Mr. Qweena'}]
# defaultdict(<class 'int'>, {'total_tags': 4})
# []
# [{'tag': 'i', 'opening_position': 10, 'closing_position': 32, 'content': 'a river thigh diner'}, {'tag': 'u', 'opening_position': 176, 'closing_position': 184, 'content': 'odona'}, {'tag': 'u', 'opening_position': 319, 'closing_position': 328, 'content': 'lay ma'}]
# defaultdict(<class 'int'>, {'total_tags': 3})
# []
# [{'tag': 'u', 'opening_position': 24, 'closing_position': 32, 'content': 'brieg'}, {'tag': 'b', 'opening_position': 36, 'closing_position': 46, 'content': 'th over'}, {'tag': 'b', 'opening_position': 69, 'closing_position': 73, 'content': 'm'}, {'tag': 'i', 'opening_position': 80, 'closing_position': 87, 'content': 'this'}, {'tag': 'b', 'opening_position': 107, 'closing_position': 113, 'content': 'has'}, {'tag': 'b', 'opening_position': 148, 'closing_position': 160, 'content': 'her phone'}, {'tag': 'u', 'opening_position': 181, 'closing_position': 189, 'content': 'phone'}, {'tag': 'b', 'opening_position': 193, 'closing_position': 209, 'content': 'alot of times'}, {'tag': 'i', 'opening_position': 218, 'closing_position': 232, 'content': 'Miss You So'}]
# defaultdict(<class 'int'>, {'total_tags': 9})
# []
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 68, 'closing_position': 75, 'content': 'must'}, {'tag': 'u', 'opening_position': 90, 'closing_position': 98, 'content': 'Early'}]
# [{'tag': 'u', 'opening_position': 28, 'closing_position': 39, 'content': 'you will'}, {'tag': 'i', 'opening_position': 53, 'closing_position': 76, 'content': 'look her into golden'}, {'tag': 'u', 'opening_position': 400, 'closing_position': 406, 'content': 'his'}]
# defaultdict(<class 'int'>, {'total_tags': 3, 'correct_tags': 1})
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 190, 'closing_position': 197, 'content': 'P. S'}, {'tag': 'u', 'opening_position': 246, 'closing_position': 253, 'content': 'wire'}]
# [{'tag': 'i', 'opening_position': 20, 'closing_position': 32, 'content': 'Telephone'}]
# defaultdict(<class 'int'>, {'total_tags': 1})
# [{'tag': 'u', 'opening_position': 16, 'closing_position': 22, 'content': 'day'}, {'tag': 'u', 'opening_position': 233, 'closing_position': 240, 'content': 'hope'}, {'tag': 'u', 'opening_position': 274, 'closing_position': 282, 'content': 'alone'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 26, 'content': 'All the very'}]
# defaultdict(<class 'int'>, {'total_tags': 1})
# [{'tag': 'u', 'opening_position': 110, 'closing_position': 115, 'content': 'do'}, {'tag': 'u', 'opening_position': 171, 'closing_position': 178, 'content': 'most'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 84, 'closing_position': 88, 'content': 'I'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 163, 'closing_position': 169, 'content': 'you'}, {'tag': 'u', 'opening_position': 187, 'closing_position': 192, 'content': 'me'}]
# [{'tag': 'u', 'opening_position': 113, 'closing_position': 119, 'content': 'low'}, {'tag': 'i', 'opening_position': 175, 'closing_position': 183, 'content': 'nuggs'}, {'tag': 'u', 'opening_position': 243, 'closing_position': 250, 'content': 'furr'}, {'tag': 'i', 'opening_position': 385, 'closing_position': 389, 'content': '-'}]
# defaultdict(<class 'int'>, {'total_tags': 4, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 361, 'closing_position': 368, 'content': 'your'}, {'tag': 'u', 'opening_position': 506, 'closing_position': 519, 'content': 'accumulate'}]
# [{'tag': 's', 'opening_position': 452, 'closing_position': 458, 'content': 'jor'}, {'tag': 'b', 'opening_position': 653, 'closing_position': 660, 'content': 'Dear'}, {'tag': 'b', 'opening_position': 686, 'closing_position': 690, 'content': 'C'}, {'tag': 'i', 'opening_position': 698, 'closing_position': 705, 'content': 'this'}, {'tag': 'u', 'opening_position': 846, 'closing_position': 853, 'content': 'jorn'}, {'tag': 's', 'opening_position': 928, 'closing_position': 932, 'content': 'n'}]
# defaultdict(<class 'int'>, {'total_tags': 6})
# [{'tag': 'u', 'opening_position': 583, 'closing_position': 589, 'content': 'all'}, {'tag': 'u', 'opening_position': 689, 'closing_position': 697, 'content': 'don’t'}, {'tag': 'u', 'opening_position': 729, 'closing_position': 737, 'content': 'often'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 161, 'closing_position': 169, 'content': 'shall'}, {'tag': 'u', 'opening_position': 424, 'closing_position': 434, 'content': 'nothing'}, {'tag': 's', 'opening_position': 476, 'closing_position': 481, 'content': 'am'}, {'tag': 'u', 'opening_position': 628, 'closing_position': 640, 'content': 'difficult'}, {'tag': 'u', 'opening_position': 705, 'closing_position': 719, 'content': 'bookbinding'}]
# [{'tag': 'i', 'opening_position': 348, 'closing_position': 381, 'content': 'is to be please- in my dearest'}, {'tag': 'i', 'opening_position': 665, 'closing_position': 672, 'content': 'feel'}, {'tag': 'u', 'opening_position': 702, 'closing_position': 711, 'content': 'wonder'}]
# defaultdict(<class 'int'>, {'total_tags': 3})
# [{'tag': 'u', 'opening_position': 196, 'closing_position': 208, 'content': 'inventory'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 39, 'closing_position': 57, 'content': 'extraordinarily'}, {'tag': 'u', 'opening_position': 467, 'closing_position': 475, 'content': 'often'}]
# [{'tag': 's', 'opening_position': 395, 'closing_position': 405, 'content': 'my gift'}, {'tag': 's', 'opening_position': 528, 'closing_position': 533, 'content': 'an'}]
# defaultdict(<class 'int'>, {'total_tags': 2})
# [{'tag': 'u', 'opening_position': 179, 'closing_position': 186, 'content': 'most'}, {'tag': 's', 'opening_position': 504, 'closing_position': 511, 'content': 'They'}, {'tag': 'u', 'opening_position': 636, 'closing_position': 644, 'content': 'Belle'}]
# [{'tag': 'u', 'opening_position': 224, 'closing_position': 239, 'content': 'Aquatic musk'}, {'tag': 'i', 'opening_position': 349, 'closing_position': 354, 'content': 'is'}, {'tag': 'i', 'opening_position': 637, 'closing_position': 648, 'content': 'Good-bye'}]
# defaultdict(<class 'int'>, {'total_tags': 3, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 19, 'closing_position': 27, 'content': 'April'}, {'tag': 'u', 'opening_position': 32, 'closing_position': 38, 'content': '9th'}, {'tag': 'u', 'opening_position': 183, 'closing_position': 188, 'content': 'so'}, {'tag': 'u', 'opening_position': 220, 'closing_position': 233, 'content': 'possessing'}, {'tag': 'u', 'opening_position': 263, 'closing_position': 268, 'content': 'My'}, {'tag': 'u', 'opening_position': 415, 'closing_position': 427, 'content': 'impatient'}]
# [{'tag': 'b', 'opening_position': 47, 'closing_position': 72, 'content': 'Friday - April 6, 1909'}, {'tag': 'b', 'opening_position': 107, 'closing_position': 114, 'content': '1909'}, {'tag': 'i', 'opening_position': 174, 'closing_position': 182, 'content': 'May -'}, {'tag': 'u', 'opening_position': 266, 'closing_position': 273, 'content': 'good'}, {'tag': 'u', 'opening_position': 291, 'closing_position': 298, 'content': 'girl'}, {'tag': 'i', 'opening_position': 374, 'closing_position': 381, 'content': 'Miss'}, {'tag': 'i', 'opening_position': 391, 'closing_position': 399, 'content': 'Brigg'}, {'tag': 'i', 'opening_position': 425, 'closing_position': 440, 'content': 'Pure - Blood'}, {'tag': 'u', 'opening_position': 562, 'closing_position': 569, 'content': 'when'}, {'tag': 'u', 'opening_position': 585, 'closing_position': 593, 'content': 'seems'}, {'tag': 'u', 'opening_position': 657, 'closing_position': 664, 'content': 'poor'}, {'tag': 'i', 'opening_position': 669, 'closing_position': 676, 'content': 'dear'}, {'tag': 'i', 'opening_position': 692, 'closing_position': 699, 'content': 'Glad'}]
# defaultdict(<class 'int'>, {'total_tags': 13, 'correct_tags': 2})
# [{'tag': 'u', 'opening_position': 164, 'closing_position': 169, 'content': 'so'}, {'tag': 's', 'opening_position': 181, 'closing_position': 188, 'content': 'that'}, {'tag': 'u', 'opening_position': 599, 'closing_position': 605, 'content': 'all'}]
# [{'tag': 'u', 'opening_position': 32, 'closing_position': 57, 'content': 'Greetings dear friend!'}]
# defaultdict(<class 'int'>, {'total_tags': 1, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 539, 'closing_position': 548, 'content': 'Belle.'}]
# [{'tag': 'b', 'opening_position': 12, 'closing_position': 36, 'content': 'Everyday warlike way,'}, {'tag': 'i', 'opening_position': 52, 'closing_position': 75, 'content': 'for my own pleasure,'}, {'tag': 'u', 'opening_position': 91, 'closing_position': 102, 'content': 'pleasure'}, {'tag': 'b', 'opening_position': 127, 'closing_position': 135, 'content': 'music'}, {'tag': 'b', 'opening_position': 143, 'closing_position': 153, 'content': 'my room'}, {'tag': 'i', 'opening_position': 163, 'closing_position': 180, 'content': 'Air & Wind'}, {'tag': 'b', 'opening_position': 198, 'closing_position': 230, 'content': 'to my own sweet satisfaction.'}, {'tag': 'b', 'opening_position': 246, 'closing_position': 251, 'content': 'If'}, {'tag': 'i', 'opening_position': 279, 'closing_position': 293, 'content': 'my own ears'}, {'tag': 'b', 'opening_position': 333, 'closing_position': 346, 'content': 'understood'}, {'tag': 'i', 'opening_position': 350, 'closing_position': 354, 'content': ','}, {'tag': 'b', 'opening_position': 362, 'closing_position': 369, 'content': 'felt'}, {'tag': 'b', 'opening_position': 380, 'closing_position': 387, 'content': 'took'}, {'tag': 'i', 'opening_position': 401, 'closing_position': 436, 'content': 'to my own pleasing satisfaction.'}]
# defaultdict(<class 'int'>, {'total_tags': 14})
# [{'tag': 'u', 'opening_position': 163, 'closing_position': 180, 'content': 'intérieurement'}, {'tag': 'u', 'opening_position': 185, 'closing_position': 209, 'content': 'il s’occupait d’amour'}, {'tag': 'u', 'opening_position': 348, 'closing_position': 365, 'content': 'extérieurement'}, {'tag': 'u', 'opening_position': 568, 'closing_position': 573, 'content': 'my'}]
# [{'tag': 'u', 'opening_position': 114, 'closing_position': 121, 'content': 'well'}, {'tag': 'i', 'opening_position': 513, 'closing_position': 517, 'content': ''}]
# defaultdict(<class 'int'>, {'total_tags': 2, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 174, 'closing_position': 181, 'content': 'dear'}, {'tag': 'u', 'opening_position': 188, 'closing_position': 195, 'content': 'when'}, {'tag': 'u', 'opening_position': 213, 'closing_position': 220, 'content': 'your'}, {'tag': 'u', 'opening_position': 353, 'closing_position': 359, 'content': 'qui'}, {'tag': 'u', 'opening_position': 364, 'closing_position': 375, 'content': 'je tiens'}, {'tag': 'u', 'opening_position': 380, 'closing_position': 387, 'content': 'pour'}, {'tag': 'u', 'opening_position': 392, 'closing_position': 405, 'content': 'inviolable'}, {'tag': 'u', 'opening_position': 458, 'closing_position': 464, 'content': 'you'}, {'tag': 'u', 'opening_position': 539, 'closing_position': 549, 'content': 'quickly'}]
# [{'tag': 'b', 'opening_position': 40, 'closing_position': 46, 'content': 'mil'}, {'tag': 'i', 'opening_position': 64, 'closing_position': 80, 'content': 'to\n        be'}, {'tag': 'u', 'opening_position': 85, 'closing_position': 90, 'content': 'go'}]
# defaultdict(<class 'int'>, {'total_tags': 3, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 41, 'closing_position': 49, 'content': 'don’t'}, {'tag': 'u', 'opening_position': 364, 'closing_position': 375, 'content': 'peculiar'}, {'tag': 'u', 'opening_position': 498, 'closing_position': 510, 'content': 'disgusted'}, {'tag': 'u', 'opening_position': 600, 'closing_position': 611, 'content': 'continue'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 34, 'content': "I'm Timthei is abl -"}, {'tag': 'i', 'opening_position': 45, 'closing_position': 50, 'content': 'mi'}, {'tag': 'b', 'opening_position': 61, 'closing_position': 66, 'content': 'ia'}, {'tag': 'i', 'opening_position': 73, 'closing_position': 83, 'content': 'Granies'}, {'tag': 'b', 'opening_position': 100, 'closing_position': 104, 'content': 'i'}, {'tag': 'i', 'opening_position': 109, 'closing_position': 113, 'content': 's'}, {'tag': 'u', 'opening_position': 130, 'closing_position': 140, 'content': 'English'}, {'tag': 'b', 'opening_position': 149, 'closing_position': 154, 'content': 'Ai'}, {'tag': 'u', 'opening_position': 170, 'closing_position': 176, 'content': 'St.'}, {'tag': 'i', 'opening_position': 209, 'closing_position': 219, 'content': "Sliit's"}, {'tag': 'i', 'opening_position': 227, 'closing_position': 237, 'content': 'English'}, {'tag': 'i', 'opening_position': 242, 'closing_position': 246, 'content': 'i'}, {'tag': 'b', 'opening_position': 149, 'closing_position': 154, 'content': 'Ai'}, {'tag': 'i', 'opening_position': 283, 'closing_position': 289, 'content': "I'm"}, {'tag': 'u', 'opening_position': 300, 'closing_position': 309, 'content': 'London'}, {'tag': 'i', 'opening_position': 318, 'closing_position': 323, 'content': 'So'}, {'tag': 'i', 'opening_position': 345, 'closing_position': 349, 'content': 'a'}, {'tag': 'u', 'opening_position': 360, 'closing_position': 365, 'content': 'St'}, {'tag': 'i', 'opening_position': 381, 'closing_position': 388, 'content': 'Soli'}, {'tag': 'u', 'opening_position': 422, 'closing_position': 428, 'content': 'Sri'}, {'tag': 'i', 'opening_position': 436, 'closing_position': 441, 'content': 'Sh'}, {'tag': 'i', 'opening_position': 453, 'closing_position': 457, 'content': 'A'}, {'tag': 'i', 'opening_position': 453, 'closing_position': 457, 'content': 'A'}, {'tag': 'b', 'opening_position': 477, 'closing_position': 481, 'content': 'D'}, {'tag': 'b', 'opening_position': 487, 'closing_position': 491, 'content': 's'}, {'tag': 'b', 'opening_position': 507, 'closing_position': 511, 'content': 'S'}, {'tag': 'i', 'opening_position': 520, 'closing_position': 525, 'content': 'of'}, {'tag': 'b', 'opening_position': 534, 'closing_position': 540, 'content': 'Rut'}, {'tag': 'b', 'opening_position': 546, 'closing_position': 550, 'content': 'n'}, {'tag': 'b', 'opening_position': 556, 'closing_position': 560, 'content': 'h'}, {'tag': 'i', 'opening_position': 571, 'closing_position': 576, 'content': 'Sn'}, {'tag': 'i', 'opening_position': 589, 'closing_position': 594, 'content': 'Po'}, {'tag': 'b', 'opening_position': 608, 'closing_position': 612, 'content': 'R'}, {'tag': 'i', 'opening_position': 616, 'closing_position': 620, 'content': 'H'}, {'tag': 'i', 'opening_position': 624, 'closing_position': 628, 'content': 'u'}, {'tag': 'b', 'opening_position': 642, 'closing_position': 646, 'content': 'T'}, {'tag': 'b', 'opening_position': 661, 'closing_position': 666, 'content': 'ab'}, {'tag': 'i', 'opening_position': 672, 'closing_position': 683, 'content': 'L'}, {'tag': 'u', 'opening_position': 675, 'closing_position': 679, 'content': 'L'}, {'tag': 'i', 'opening_position': 688, 'closing_position': 692, 'content': 'P'}, {'tag': 'b', 'opening_position': 707, 'closing_position': 712, 'content': 'in'}, {'tag': 'b', 'opening_position': 487, 'closing_position': 491, 'content': 's'}, {'tag': 'i', 'opening_position': 743, 'closing_position': 748, 'content': 'sn'}, {'tag': 'i', 'opening_position': 743, 'closing_position': 748, 'content': 'sn'}, {'tag': 'i', 'opening_position': 743, 'closing_position': 748, 'content': 'sn'}, {'tag': 'i', 'opening_position': 773, 'closing_position': 777, 'content': 'S'}]
# defaultdict(<class 'int'>, {'total_tags': 46})
# [{'tag': 'u', 'opening_position': 31, 'closing_position': 42, 'content': 'in spite'}, {'tag': 'u', 'opening_position': 327, 'closing_position': 333, 'content': 'you'}, {'tag': 'u', 'opening_position': 425, 'closing_position': 437, 'content': 'another’s'}, {'tag': 'u', 'opening_position': 489, 'closing_position': 499, 'content': 'hateful'}, {'tag': 'u', 'opening_position': 560, 'closing_position': 565, 'content': 'so'}]
# [{'tag': 'i', 'opening_position': 219, 'closing_position': 235, 'content': 'home on faith'}, {'tag': 'u', 'opening_position': 250, 'closing_position': 275, 'content': 'been the last few days'}, {'tag': 's', 'opening_position': 287, 'closing_position': 340, 'content': 'returned as the Cegnon the river'}]
# defaultdict(<class 'int'>, {'total_tags': 3, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 26, 'closing_position': 35, 'content': 'Sunday'}]
# [{'tag': 'i', 'opening_position': 37, 'closing_position': 45, 'content': 'Saefl'}, {'tag': 'i', 'opening_position': 69, 'closing_position': 77, 'content': 'glory'}, {'tag': 'i', 'opening_position': 103, 'closing_position': 109, 'content': 'hum'}, {'tag': 'u', 'opening_position': 123, 'closing_position': 146, 'content': 'allium - more nt for'}, {'tag': 'i', 'opening_position': 156, 'closing_position': 165, 'content': 'murmer'}, {'tag': 'i', 'opening_position': 238, 'closing_position': 243, 'content': 'am'}, {'tag': 'i', 'opening_position': 268, 'closing_position': 275, 'content': 'that'}]
# defaultdict(<class 'int'>, {'total_tags': 7})
# []
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# []
# [{'tag': 'i', 'opening_position': 23, 'closing_position': 42, 'content': 'please very loud'}, {'tag': 'b', 'opening_position': 51, 'closing_position': 73, 'content': 'speak at my face to'}, {'tag': 'i', 'opening_position': 87, 'closing_position': 98, 'content': 'face and'}, {'tag': 'b', 'opening_position': 113, 'closing_position': 144, 'content': 'hide myeyes from me:'}, {'tag': 'i', 'opening_position': 124, 'closing_position': 139, 'content': 'eyes from me'}, {'tag': 'b', 'opening_position': 152, 'closing_position': 180, 'content': 'banks runneth overflowing'}, {'tag': 'i', 'opening_position': 211, 'closing_position': 253, 'content': 'I see him; I caip to myself; I can feel'}, {'tag': 'i', 'opening_position': 301, 'closing_position': 324, 'content': 'hour when I miss him'}, {'tag': 'b', 'opening_position': 352, 'closing_position': 365, 'content': 'excellence'}, {'tag': 'i', 'opening_position': 386, 'closing_position': 413, 'content': 'ground where he has gone'}, {'tag': 'i', 'opening_position': 429, 'closing_position': 453, 'content': 'hour when I miss him.'}, {'tag': 'b', 'opening_position': 466, 'closing_position': 485, 'content': 'smellit:'}, {'tag': 'i', 'opening_position': 475, 'closing_position': 480, 'content': 'it'}, {'tag': 'i', 'opening_position': 508, 'closing_position': 527, 'content': 'smelling me this'}, {'tag': 'b', 'opening_position': 539, 'closing_position': 558, 'content': 'air of the earth'}, {'tag': 'b', 'opening_position': 572, 'closing_position': 595, 'content': 'forgotten on face of'}, {'tag': 'i', 'opening_position': 644, 'closing_position': 658, 'content': 'smell of me'}, {'tag': 'b', 'opening_position': 703, 'closing_position': 728, 'content': 'dull of mydull'}, {'tag': 'i', 'opening_position': 717, 'closing_position': 724, 'content': 'dull'}, {'tag': 'i', 'opening_position': 739, 'closing_position': 852, 'content': 'ground, and howdeeply into his heart— you —me — a part of my heart— that is all of this.'}, {'tag': 'i', 'opening_position': 762, 'closing_position': 786, 'content': 'deeply into his heart'}, {'tag': 'u', 'opening_position': 799, 'closing_position': 825, 'content': 'me — a part of my heart'}]
# defaultdict(<class 'int'>, {'total_tags': 22})
# [{'tag': 'u', 'opening_position': 75, 'closing_position': 82, 'content': 'real'}, {'tag': 'u', 'opening_position': 807, 'closing_position': 815, 'content': 'Belle'}]
# defaultdict(<class 'int'>, {'total_tags': 0})
# []
# [{'tag': 'u', 'opening_position': 121, 'closing_position': 130, 'content': 'brass:'}, {'tag': 'u', 'opening_position': 253, 'closing_position': 265, 'content': 'forgiven:'}, {'tag': 'u', 'opening_position': 307, 'closing_position': 316, 'content': 'poison'}]
# defaultdict(<class 'int'>, {'total_tags': 3})
# [{'tag': 'u', 'opening_position': 426, 'closing_position': 434, 'content': 'cruel'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 206, 'closing_position': 212, 'content': 'you'}, {'tag': 'u', 'opening_position': 228, 'closing_position': 236, 'content': 'never'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 93, 'content': 'Muriel is the Mother ofGraceFranklin'}, {'tag': 'u', 'opening_position': 64, 'closing_position': 72, 'content': 'Grace'}, {'tag': 'i', 'opening_position': 77, 'closing_position': 88, 'content': 'Franklin'}, {'tag': 'i', 'opening_position': 156, 'closing_position': 163, 'content': 'Vern'}, {'tag': 'b', 'opening_position': 177, 'closing_position': 189, 'content': 'astronaut'}, {'tag': 'b', 'opening_position': 246, 'closing_position': 253, 'content': 'Mari'}, {'tag': 'i', 'opening_position': 311, 'closing_position': 317, 'content': 'and'}, {'tag': 'i', 'opening_position': 311, 'closing_position': 317, 'content': 'and'}, {'tag': 'b', 'opening_position': 475, 'closing_position': 483, 'content': "dad's"}, {'tag': 'i', 'opening_position': 497, 'closing_position': 504, 'content': 'eyes'}, {'tag': 'i', 'opening_position': 541, 'closing_position': 549, 'content': 'Merry'}, {'tag': 'b', 'opening_position': 627, 'closing_position': 636, 'content': 'Carrot'}, {'tag': 'i', 'opening_position': 665, 'closing_position': 672, 'content': 'pink'}]
# defaultdict(<class 'int'>, {'total_tags': 13, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 178, 'closing_position': 186, 'content': 'early'}, {'tag': 'u', 'opening_position': 390, 'closing_position': 402, 'content': 'something'}, {'tag': 'u', 'opening_position': 490, 'closing_position': 497, 'content': 'mere'}, {'tag': 's', 'opening_position': 528, 'closing_position': 532, 'content': 'n'}, {'tag': 'u', 'opening_position': 390, 'closing_position': 402, 'content': 'something'}, {'tag': 'u', 'opening_position': 630, 'closing_position': 637, 'content': 'from'}, {'tag': 'u', 'opening_position': 642, 'closing_position': 651, 'content': 'itself'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 680, 'closing_position': 690, 'content': 'flooded'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 250, 'closing_position': 260, 'content': 'amusing'}, {'tag': 'u', 'opening_position': 366, 'closing_position': 380, 'content': 'interviewed'}, {'tag': 'u', 'opening_position': 503, 'closing_position': 510, 'content': 'golf'}]
# [{'tag': 'i', 'opening_position': 1187, 'closing_position': 1392, 'content': 'priest**and not only abouthis hands andmoney*to me, I can guess it if*I knew his handsand money, thenof course.*'}]
# defaultdict(<class 'int'>, {'total_tags': 1})
# [{'tag': 'u', 'opening_position': 34, 'closing_position': 40, 'content': 'his'}, {'tag': 'u', 'opening_position': 181, 'closing_position': 192, 'content': 'negative'}, {'tag': 'u', 'opening_position': 413, 'closing_position': 420, 'content': 'know'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 69, 'closing_position': 77, 'content': 'awful'}]
# [{'tag': 'i', 'opening_position': 50, 'closing_position': 55, 'content': 'He'}, {'tag': 'b', 'opening_position': 80, 'closing_position': 86, 'content': 'the'}, {'tag': 'i', 'opening_position': 116, 'closing_position': 130, 'content': 'magnificent'}, {'tag': 's', 'opening_position': 150, 'closing_position': 167, 'content': 'is not too far'}, {'tag': 'i', 'opening_position': 227, 'closing_position': 234, 'content': '(He)'}, {'tag': 'u', 'opening_position': 249, 'closing_position': 258, 'content': 'gone'}, {'tag': 'i', 'opening_position': 227, 'closing_position': 234, 'content': '(He)'}, {'tag': 'u', 'opening_position': 300, 'closing_position': 306, 'content': 'The'}, {'tag': 'b', 'opening_position': 311, 'closing_position': 317, 'content': 'few'}, {'tag': 's', 'opening_position': 355, 'closing_position': 361, 'content': 'now'}, {'tag': 'u', 'opening_position': 464, 'closing_position': 487, 'content': 'Lewy - haling a mel-'}, {'tag': 'i', 'opening_position': 520, 'closing_position': 526, 'content': 'sit'}, {'tag': 'b', 'opening_position': 596, 'closing_position': 602, 'content': 'dis'}, {'tag': 'i', 'opening_position': 787, 'closing_position': 792, 'content': 'me'}, {'tag': 's', 'opening_position': 916, 'closing_position': 924, 'content': 'brown'}]
# defaultdict(<class 'int'>, {'total_tags': 15})
# [{'tag': 'u', 'opening_position': 25, 'closing_position': 32, 'content': '19th'}, {'tag': 'u', 'opening_position': 66, 'closing_position': 77, 'content': 'Virginia'}, {'tag': 'u', 'opening_position': 158, 'closing_position': 165, 'content': 'most'}, {'tag': 's', 'opening_position': 384, 'closing_position': 390, 'content': 'but'}, {'tag': 'u', 'opening_position': 748, 'closing_position': 754, 'content': 'why'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 's', 'opening_position': 232, 'closing_position': 240, 'content': 'great'}, {'tag': 'u', 'opening_position': 493, 'closing_position': 499, 'content': 'owe'}, {'tag': 'u', 'opening_position': 581, 'closing_position': 590, 'content': 'porous'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 16, 'content': 'he'}, {'tag': 'i', 'opening_position': 47, 'closing_position': 55, 'content': 'enemy'}, {'tag': 'i', 'opening_position': 84, 'closing_position': 90, 'content': 'and'}, {'tag': 'i', 'opening_position': 157, 'closing_position': 165, 'content': 'still'}, {'tag': 'i', 'opening_position': 187, 'closing_position': 193, 'content': 'him'}, {'tag': 'i', 'opening_position': 269, 'closing_position': 280, 'content': 'distress'}, {'tag': 'b', 'opening_position': 349, 'closing_position': 359, 'content': 'was the'}, {'tag': 'b', 'opening_position': 395, 'closing_position': 408, 'content': 'few'}, {'tag': 'u', 'opening_position': 398, 'closing_position': 404, 'content': 'few'}, {'tag': 'i', 'opening_position': 426, 'closing_position': 435, 'content': 'altain'}, {'tag': 'b', 'opening_position': 476, 'closing_position': 483, 'content': 'very'}]
# defaultdict(<class 'int'>, {'total_tags': 11})
# [{'tag': 'u', 'opening_position': 150, 'closing_position': 156, 'content': 'you'}, {'tag': 'u', 'opening_position': 203, 'closing_position': 210, 'content': 'most'}, {'tag': 'u', 'opening_position': 277, 'closing_position': 284, 'content': 'I do'}, {'tag': 'u', 'opening_position': 303, 'closing_position': 308, 'content': 'no'}, {'tag': 'u', 'opening_position': 303, 'closing_position': 308, 'content': 'no'}]
# [{'tag': 'b', 'opening_position': 173, 'closing_position': 1104, 'content': "her former morn. Jane's daughterJane's mother, Sister-Jones' child & wifeHer 4I don't know& & in a strangemanner.me& the girlmeet.Iwas tome in myto my country hometo thecountryeachmanner.I can't, I can't live with you,I must keep house.I must keep house. I can't live this way.Thursday morn.-Fernnow my madds beckman - I mean - they don'tBetty's mother - they wereI only can be your -- your friend - so far as Iam to - & I love you dearly. Don't think\n        I love you, my dear-"}, {'tag': 'i', 'opening_position': 322, 'closing_position': 337, 'content': "I don't know"}, {'tag': 'b', 'opening_position': 412, 'closing_position': 417, 'content': 'me'}, {'tag': 'b', 'opening_position': 477, 'closing_position': 481, 'content': 'I'}, {'tag': 'b', 'opening_position': 579, 'closing_position': 589, 'content': 'country'}, {'tag': 's', 'opening_position': 608, 'closing_position': 766, 'content': "manner.I can't, I can't live with you,I must keep house.I must keep house. I can't live this way."}, {'tag': 'b', 'opening_position': 778, 'closing_position': 795, 'content': 'Thursday morn.'}, {'tag': 'b', 'opening_position': 932, 'closing_position': 955, 'content': 'I only can be your -'}]
# defaultdict(<class 'int'>, {'total_tags': 8})
# [{'tag': 'u', 'opening_position': 462, 'closing_position': 477, 'content': 'spell it out'}, {'tag': 'u', 'opening_position': 526, 'closing_position': 532, 'content': 'not'}, {'tag': 'u', 'opening_position': 566, 'closing_position': 573, 'content': 'Love'}, {'tag': 's', 'opening_position': 590, 'closing_position': 613, 'content': 'I want à moi – je ne'}]
# [{'tag': 'b', 'opening_position': 448, 'closing_position': 452, 'content': 'N'}, {'tag': 'i', 'opening_position': 505, 'closing_position': 519, 'content': 'I mean only'}]
# defaultdict(<class 'int'>, {'total_tags': 2})
# [{'tag': 'u', 'opening_position': 63, 'closing_position': 76, 'content': 'villainous'}, {'tag': 'u', 'opening_position': 172, 'closing_position': 180, 'content': 'awful'}, {'tag': 'u', 'opening_position': 287, 'closing_position': 296, 'content': 'refuse'}, {'tag': 'u', 'opening_position': 400, 'closing_position': 406, 'content': 'saw'}, {'tag': 'u', 'opening_position': 491, 'closing_position': 495, 'content': 'I'}, {'tag': 'u', 'opening_position': 538, 'closing_position': 549, 'content': 'J. D. R.'}, {'tag': 'u', 'opening_position': 639, 'closing_position': 644, 'content': 'at'}, {'tag': 'u', 'opening_position': 649, 'closing_position': 656, 'content': 'once'}]
# [{'tag': 'i', 'opening_position': 11, 'closing_position': 39, 'content': 'A wire old owt sart in an'}, {'tag': 'i', 'opening_position': 60, 'closing_position': 83, 'content': 'The neere the owt he'}, {'tag': 'i', 'opening_position': 115, 'closing_position': 144, 'content': 'The leere he fare the more'}, {'tag': 'b', 'opening_position': 204, 'closing_position': 222, 'content': 'A wire old bird'}, {'tag': 'b', 'opening_position': 245, 'closing_position': 268, 'content': 'China bis hat Tom D.'}, {'tag': 'b', 'opening_position': 285, 'closing_position': 307, 'content': 'Bergerelser rurn me'}, {'tag': 'b', 'opening_position': 333, 'closing_position': 356, 'content': 'Supfine he had a Jop'}]
# defaultdict(<class 'int'>, {'total_tags': 7})
# [{'tag': 'u', 'opening_position': 387, 'closing_position': 404, 'content': 'confiteor tibi'}, {'tag': 'u', 'opening_position': 671, 'closing_position': 679, 'content': 'never'}, {'tag': 's', 'opening_position': 829, 'closing_position': 845, 'content': 'any more that'}]
# [{'tag': 'b', 'opening_position': 26, 'closing_position': 56, 'content': 'kidsluye sentine frehistnel'}, {'tag': 'i', 'opening_position': 61, 'closing_position': 71, 'content': 'by hein'}, {'tag': 'i', 'opening_position': 451, 'closing_position': 467, 'content': 'his ruod meil'}]
# defaultdict(<class 'int'>, {'total_tags': 3})
# [{'tag': 'u', 'opening_position': 520, 'closing_position': 528, 'content': 'would'}, {'tag': 'u', 'opening_position': 642, 'closing_position': 651, 'content': 'desire'}]
# [{'tag': 'u', 'opening_position': 10, 'closing_position': 29, 'content': 'I will not allow'}, {'tag': 'i', 'opening_position': 116, 'closing_position': 133, 'content': 'shame of Jesus'}, {'tag': 'i', 'opening_position': 197, 'closing_position': 209, 'content': 'Israelian'}, {'tag': 'u', 'opening_position': 351, 'closing_position': 356, 'content': 'is'}, {'tag': 'b', 'opening_position': 369, 'closing_position': 378, 'content': 'Narnia'}, {'tag': 'i', 'opening_position': 391, 'closing_position': 399, 'content': 'years'}, {'tag': 'u', 'opening_position': 406, 'closing_position': 439, 'content': 'i have taken so many people. I'}, {'tag': 'u', 'opening_position': 458, 'closing_position': 469, 'content': 'teaching'}, {'tag': 'i', 'opening_position': 555, 'closing_position': 560, 'content': 'my'}, {'tag': 'b', 'opening_position': 590, 'closing_position': 594, 'content': 'n'}, {'tag': 'b', 'opening_position': 626, 'closing_position': 634, 'content': 'light'}, {'tag': 'b', 'opening_position': 650, 'closing_position': 660, 'content': 'drawing'}, {'tag': 'b', 'opening_position': 681, 'closing_position': 691, 'content': 'holding'}, {'tag': 'b', 'opening_position': 709, 'closing_position': 723, 'content': 'great light'}]
# defaultdict(<class 'int'>, {'total_tags': 14, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 700, 'closing_position': 719, 'content': 'are cheaply lost'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 252, 'closing_position': 260, 'content': 'quite'}, {'tag': 'u', 'opening_position': 265, 'closing_position': 271, 'content': 'mad'}, {'tag': 'u', 'opening_position': 451, 'closing_position': 458, 'content': 'know'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 19, 'closing_position': 27, 'content': 'April'}, {'tag': 'u', 'opening_position': 522, 'closing_position': 527, 'content': 'my'}, {'tag': 'u', 'opening_position': 551, 'closing_position': 559, 'content': 'yours'}]
# ...
# defaultdict(<class 'int'>, {'total_tags': 13, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 179, 'closing_position': 186, 'content': 'very'}, {'tag': 'u', 'opening_position': 218, 'closing_position': 227, 'content': 'minute'}, {'tag': 'u', 'opening_position': 269, 'closing_position': 279, 'content': 'pretend'}, {'tag': 'u', 'opening_position': 179, 'closing_position': 186, 'content': 'very'}]
# [{'tag': 'b', 'opening_position': 166, 'closing_position': 197, 'content': "Ware's Angel Dauphine"}, {'tag': 'i', 'opening_position': 169, 'closing_position': 193, 'content': "Ware's Angel Dauphine"}, {'tag': 'b', 'opening_position': 278, 'closing_position': 320, 'content': 'little election in lee'}, {'tag': 'i', 'opening_position': 330, 'closing_position': 363, 'content': "Let's lec tro"}, {'tag': 'i', 'opening_position': 373, 'closing_position': 390, 'content': 'Ellichin deuce'}, {'tag': 'i', 'opening_position': 437, 'closing_position': 453, 'content': 'hear you last'}, {'tag': 'i', 'opening_position': 470, 'closing_position': 488, 'content': 'Romanian I bece'}]
# defaultdict(<class 'int'>, {'total_tags': 7})
# [{'tag': 'u', 'opening_position': 132, 'closing_position': 142, 'content': 'without'}, {'tag': 'u', 'opening_position': 147, 'closing_position': 155, 'content': 'doubt'}]
# [{'tag': 'b', 'opening_position': 224, 'closing_position': 236, 'content': 'Uncle com'}]
# defaultdict(<class 'int'>, {'total_tags': 1})
# [{'tag': 'u', 'opening_position': 347, 'closing_position': 354, 'content': 'real'}]
# [{'tag': 'b', 'opening_position': 67, 'closing_position': 75, 'content': 'While'}, {'tag': 'i', 'opening_position': 172, 'closing_position': 177, 'content': 'in'}, {'tag': 'b', 'opening_position': 182, 'closing_position': 187, 'content': 'my'}, {'tag': 'i', 'opening_position': 230, 'closing_position': 235, 'content': 'is'}, {'tag': 'b', 'opening_position': 240, 'closing_position': 247, 'content': "no's"}, {'tag': 'i', 'opening_position': 288, 'closing_position': 300, 'content': 'lettering'}, {'tag': 's', 'opening_position': 345, 'closing_position': 356, 'content': 'some day'}, {'tag': 'u', 'opening_position': 365, 'closing_position': 384, 'content': 'I mean in a year'}, {'tag': 'u', 'opening_position': 420, 'closing_position': 430, 'content': 'you are'}, {'tag': 'u', 'opening_position': 517, 'closing_position': 551, 'content': 'some day and I mean the day you'}, {'tag': 'i', 'opening_position': 653, 'closing_position': 659, 'content': 'for'}, {'tag': 'b', 'opening_position': 806, 'closing_position': 813, 'content': 'Very'}, {'tag': 'b', 'opening_position': 860, 'closing_position': 878, 'content': 'Iris F. Probert'}]
# defaultdict(<class 'int'>, {'total_tags': 13})
# [{'tag': 'u', 'opening_position': 134, 'closing_position': 139, 'content': 'so'}, {'tag': 'u', 'opening_position': 297, 'closing_position': 305, 'content': 'every'}, {'tag': 'u', 'opening_position': 407, 'closing_position': 421, 'content': 'immediately'}, {'tag': 'u', 'opening_position': 486, 'closing_position': 495, 'content': 'single'}, {'tag': 'u', 'opening_position': 696, 'closing_position': 701, 'content': 'do'}, {'tag': 'u', 'opening_position': 706, 'closing_position': 714, 'content': 'still'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 115, 'closing_position': 121, 'content': 'any'}, {'tag': 'u', 'opening_position': 292, 'closing_position': 299, 'content': 'make'}, {'tag': 'u', 'opening_position': 351, 'closing_position': 357, 'content': 'her'}, {'tag': 'u', 'opening_position': 669, 'closing_position': 676, 'content': 'word'}, {'tag': 'u', 'opening_position': 729, 'closing_position': 739, 'content': 'furious'}]
# [{'tag': 'b', 'opening_position': 212, 'closing_position': 218, 'content': 'awe'}, {'tag': 'i', 'opening_position': 290, 'closing_position': 306, 'content': 'girl with big'}, {'tag': 'i', 'opening_position': 415, 'closing_position': 426, 'content': 'not well'}, {'tag': 'i', 'opening_position': 452, 'closing_position': 473, 'content': 'and I wonder I did'}, {'tag': 's', 'opening_position': 561, 'closing_position': 566, 'content': 'he'}, {'tag': 's', 'opening_position': 635, 'closing_position': 642, 'content': 'wife'}]
# defaultdict(<class 'int'>, {'total_tags': 6})
# [{'tag': 'u', 'opening_position': 197, 'closing_position': 209, 'content': 'every one'}, {'tag': 'u', 'opening_position': 491, 'closing_position': 496, 'content': 'my'}, {'tag': 'u', 'opening_position': 717, 'closing_position': 732, 'content': 'with meaning'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 498, 'closing_position': 504, 'content': 'him'}, {'tag': 'u', 'opening_position': 676, 'closing_position': 685, 'content': 'divine'}, {'tag': 'u', 'opening_position': 748, 'closing_position': 754, 'content': 'how'}, {'tag': 'u', 'opening_position': 778, 'closing_position': 786, 'content': 'Belle'}, {'tag': 'i', 'opening_position': 801, 'closing_position': 825, 'content': 'in secretarial script'}]
# [{'tag': 'b', 'opening_position': 20, 'closing_position': 50, 'content': 'Polish beer & I like it'}, {'tag': 'u', 'opening_position': 55, 'closing_position': 89, 'content': 'a little bis Mr. & I use to'}, {'tag': 'b', 'opening_position': 140, 'closing_position': 170, 'content': 'used to make her drink much'}, {'tag': 's', 'opening_position': 179, 'closing_position': 186, 'content': 'beer'}, {'tag': 'i', 'opening_position': 224, 'closing_position': 228, 'content': '\\'}, {'tag': 'u', 'opening_position': 342, 'closing_position': 357, 'content': 'Verrardh (?)'}, {'tag': 'i', 'opening_position': 224, 'closing_position': 228, 'content': '\\'}, {'tag': 'i', 'opening_position': 224, 'closing_position': 228, 'content': '\\'}, {'tag': 'b', 'opening_position': 600, 'closing_position': 626, 'content': 'In theapartment'}, {'tag': 'u', 'opening_position': 610, 'closing_position': 622, 'content': 'apartment'}, {'tag': 'i', 'opening_position': 224, 'closing_position': 228, 'content': '\\'}]
# defaultdict(<class 'int'>, {'total_tags': 11, 'correct_tags': 2})
# [{'tag': 'u', 'opening_position': 109, 'closing_position': 115, 'content': 'Now'}, {'tag': 'u', 'opening_position': 193, 'closing_position': 198, 'content': 'am'}, {'tag': 'u', 'opening_position': 310, 'closing_position': 319, 'content': 'Sister'}, {'tag': 'u', 'opening_position': 645, 'closing_position': 650, 'content': 'me'}, {'tag': 'u', 'opening_position': 693, 'closing_position': 699, 'content': 'you'}, {'tag': 's', 'opening_position': 755, 'closing_position': 763, 'content': 'acted'}, {'tag': 'u', 'opening_position': 781, 'closing_position': 785, 'content': 'I'}, {'tag': 'u', 'opening_position': 823, 'closing_position': 832, 'content': 'course'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# [{'tag': 'u', 'opening_position': 316, 'closing_position': 320, 'content': 'I'}, {'tag': 'u', 'opening_position': 727, 'closing_position': 735, 'content': 'child'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 39, 'content': 'Hear I use the bon gram E'}, {'tag': 'u', 'opening_position': 258, 'closing_position': 267, 'content': 'babies'}, {'tag': 'u', 'opening_position': 277, 'closing_position': 306, 'content': 'I want you love her - she'}, {'tag': 'u', 'opening_position': 407, 'closing_position': 416, 'content': 'I want'}, {'tag': 'u', 'opening_position': 643, 'closing_position': 652, 'content': 'please'}]
# defaultdict(<class 'int'>, {'total_tags': 5, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 81, 'closing_position': 90, 'content': 'insist'}, {'tag': 'u', 'opening_position': 210, 'closing_position': 219, 'content': 'father'}, {'tag': 'u', 'opening_position': 535, 'closing_position': 542, 'content': 'even'}, {'tag': 'u', 'opening_position': 767, 'closing_position': 773, 'content': 'any'}]
# [{'tag': 'b', 'opening_position': 11, 'closing_position': 17, 'content': 'She'}, {'tag': 's', 'opening_position': 50, 'closing_position': 61, 'content': 'used the'}, {'tag': 'b', 'opening_position': 145, 'closing_position': 153, 'content': 'makes'}, {'tag': 'b', 'opening_position': 184, 'closing_position': 190, 'content': 'And'}, {'tag': 'i', 'opening_position': 199, 'closing_position': 216, 'content': 'the record all'}, {'tag': 'b', 'opening_position': 299, 'closing_position': 305, 'content': 'for'}, {'tag': 'b', 'opening_position': 540, 'closing_position': 548, 'content': 'knows'}, {'tag': 'i', 'opening_position': 635, 'closing_position': 642, 'content': 'toll'}]
# defaultdict(<class 'int'>, {'total_tags': 8})
# [{'tag': 'u', 'opening_position': 118, 'closing_position': 125, 'content': 'very'}, {'tag': 'u', 'opening_position': 418, 'closing_position': 425, 'content': 'love'}]
# [{'tag': 'u', 'opening_position': 14, 'closing_position': 44, 'content': 'lyrics of the grandest kind'}, {'tag': 'u', 'opening_position': 55, 'closing_position': 83, 'content': 'globe’s most golden sound'}, {'tag': 'u', 'opening_position': 93, 'closing_position': 103, 'content': 'radiant'}, {'tag': 'i', 'opening_position': 108, 'closing_position': 124, 'content': 'and brightest'}, {'tag': 'b', 'opening_position': 163, 'closing_position': 912, 'content': 'are alsothat you canprefer,and so farthe world’sall butone\nof those\nwho’ve found theworld’sgrandest fun, andher wordsdreadlythe last few wordsher lyricsevery linefor her, they\ndo like to listen to, every one of them\ndoesdazzleand shine so differently from \nthey are all here \nher\nthose people was\nso happy \nmelie as wellhereandliveas happy and cheerfulas you will hereand I feel as thesmallestkind of can\nthe difference between her and \nher friends who’d done\nme here \nandmost unluckyme \nand you’llfind we’re all here as happyas \nthe worldneverwas.'}, {'tag': 'b', 'opening_position': 208, 'closing_position': 221, 'content': 'and so far'}, {'tag': 'b', 'opening_position': 238, 'closing_position': 248, 'content': 'all but'}, {'tag': 'i', 'opening_position': 283, 'closing_position': 293, 'content': 'world’s'}, {'tag': 'u', 'opening_position': 316, 'closing_position': 328, 'content': 'her words'}, {'tag': 'b', 'opening_position': 333, 'closing_position': 343, 'content': 'dreadly'}, {'tag': 'u', 'opening_position': 384, 'closing_position': 397, 'content': 'her lyrics'}, {'tag': 'b', 'opening_position': 402, 'closing_position': 415, 'content': 'every line'}, {'tag': 'u', 'opening_position': 479, 'closing_position': 488, 'content': 'dazzle'}, {'tag': 'b', 'opening_position': 577, 'closing_position': 591, 'content': 'lie as well'}, {'tag': 'b', 'opening_position': 601, 'closing_position': 607, 'content': 'and'}, {'tag': 'b', 'opening_position': 657, 'closing_position': 676, 'content': 'as you will here'}, {'tag': 'i', 'opening_position': 699, 'closing_position': 710, 'content': 'smallest'}, {'tag': 'u', 'opening_position': 840, 'closing_position': 871, 'content': 'find we’re all here as happy'}, {'tag': 'u', 'opening_position': 890, 'closing_position': 898, 'content': 'never'}]
# defaultdict(<class 'int'>, {'total_tags': 19, 'correct_tags': 2})
# [{'tag': 'u', 'opening_position': 88, 'closing_position': 93, 'content': 'so'}, {'tag': 'u', 'opening_position': 123, 'closing_position': 132, 'content': 'things'}, {'tag': 's', 'opening_position': 517, 'closing_position': 525, 'content': 'night'}]
# []
# defaultdict(<class 'int'>, {'total_tags': 0})
# []
# [{'tag': 'i', 'opening_position': 63, 'closing_position': 67, 'content': 'I'}, {'tag': 'i', 'opening_position': 223, 'closing_position': 231, 'content': 'where'}, {'tag': 'i', 'opening_position': 329, 'closing_position': 335, 'content': 'see'}, {'tag': 'b', 'opening_position': 344, 'closing_position': 350, 'content': 'bus'}, {'tag': 'i', 'opening_position': 379, 'closing_position': 384, 'content': 'is'}, {'tag': 'i', 'opening_position': 475, 'closing_position': 482, 'content': 'from'}, {'tag': 'b', 'opening_position': 695, 'closing_position': 702, 'content': 'wife'}, {'tag': 'u', 'opening_position': 776, 'closing_position': 784, 'content': 'diner'}, {'tag': 'i', 'opening_position': 801, 'closing_position': 807, 'content': 'yes'}, {'tag': 'u', 'opening_position': 906, 'closing_position': 921, 'content': 'one more man'}, {'tag': 'i', 'opening_position': 970, 'closing_position': 977, 'content': 'wife'}]
# defaultdict(<class 'int'>, {'total_tags': 11})
# [{'tag': 'u', 'opening_position': 280, 'closing_position': 285, 'content': 'do'}, {'tag': 'u', 'opening_position': 370, 'closing_position': 378, 'content': 'Belle'}]
# [{'tag': 'i', 'opening_position': 26, 'closing_position': 33, 'content': 'rega'}, {'tag': 'b', 'opening_position': 116, 'closing_position': 124, 'content': 'Salie'}, {'tag': 'u', 'opening_position': 136, 'closing_position': 145, 'content': 'London'}]
# defaultdict(<class 'int'>, {'total_tags': 3})
# [{'tag': 'u', 'opening_position': 553, 'closing_position': 564, 'content': 'giddiest'}]
# [{'tag': 'b', 'opening_position': 107, 'closing_position': 136, 'content': 'inmp his son Jolvi is Gong'}, {'tag': 'b', 'opening_position': 141, 'closing_position': 162, 'content': 'do jo taeor piro -'}, {'tag': 'b', 'opening_position': 173, 'closing_position': 199, 'content': 'my dear ojil u Carlie -'}, {'tag': 'i', 'opening_position': 204, 'closing_position': 228, 'content': 'Lehru found m yesdel,'}]
# defaultdict(<class 'int'>, {'total_tags': 4})
# [{'tag': 'u', 'opening_position': 232, 'closing_position': 239, 'content': 'deep'}]
# [{'tag': 'u', 'opening_position': 26, 'closing_position': 51, 'content': 'Mr. To feel your love,'}, {'tag': 'u', 'opening_position': 55, 'closing_position': 66, 'content': 'you must'}]
# defaultdict(<class 'int'>, {'total_tags': 2, 'correct_tags': 1})
# [{'tag': 'u', 'opening_position': 677, 'closing_position': 693, 'content': 'provisionally'}]
# [{'tag': 'b', 'opening_position': 142, 'closing_position': 165, 'content': 'Again as soon as any'}, {'tag': 'i', 'opening_position': 177, 'closing_position': 186, 'content': 'father'}, {'tag': 'i', 'opening_position': 332, 'closing_position': 341, 'content': 'Father'}]
# defaultdict(<class 'int'>, {'total_tags': 3})
# [{'tag': 'i', 'opening_position': 239, 'closing_position': 259, 'content': 'double underlined'}, {'tag': 'u', 'opening_position': 277, 'closing_position': 284, 'content': 'form'}, {'tag': 'u', 'opening_position': 442, 'closing_position': 454, 'content': 'consigned'}, {'tag': 'u', 'opening_position': 277, 'closing_position': 284, 'content': 'form'}, {'tag': 'u', 'opening_position': 534, 'closing_position': 547, 'content': 'especially'}, {'tag': 'u', 'opening_position': 607, 'closing_position': 613, 'content': 'too'}, {'tag': 'u', 'opening_position': 679, 'closing_position': 686, 'content': 'only'}]
# [{'tag': 'i', 'opening_position': 121, 'closing_position': 137, 'content': 'Felice Natale'}, {'tag': 'u', 'opening_position': 450, 'closing_position': 458, 'content': '$120.'}, {'tag': 'u', 'opening_position': 806, 'closing_position': 823, 'content': 'overnite mail.'}, {'tag': 'u', 'opening_position': 849, 'closing_position': 916, 'content': 'I hope someday you will look at that one which will do you good.'}]
# defaultdict(<class 'int'>, {'total_tags': 4, 'correct_tags': 4})
#
# Risultati finali su tutti i file processati:
# Totale tag processati: 3078
# Percentuale di tag correttamente riconosciuti: 7.60%
# Percentuale di posizioni corrette: 0.00%
# Percentuale di contenuti corrispondenti: 0.00%
# Percentuale di corrispondenze perfette (tag, contenuto e posizione): 0.00%
