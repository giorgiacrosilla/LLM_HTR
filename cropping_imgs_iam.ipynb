# %%
import os
from PIL import Image

# Define the input and output folder paths
input_folder = 'IAM/aachen_validation_set'  # Folder containing the images
output_folder = 'IAM/IAMa_cropped'  # Folder to save the cropped images

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Function to crop an image
def crop_image(image, crop_box):
    return image.crop(crop_box)

# Loop through all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith(('.png', '.jpg', '.jpeg', '.bmp', '.tiff')):  # Add more extensions if needed
        # Open an image file
        img_path = os.path.join(input_folder, filename)
        with Image.open(img_path) as img:
            # Get image dimensions (width, height)
            width, height = img.size

            # Define a cropping box (crop 10% from top and bottom only)
            left = 0  # No cropping on the left
            top = height * 0.11  # Crop 10% from the top
            right = width  # No cropping on the right
            bottom = height * 0.95  # Crop 10% from the bottom

            # Crop the image
            cropped_img = crop_image(img, (left, top, right, bottom))

            # Save the cropped image to the output folder
            cropped_img.save(os.path.join(output_folder, filename))

print("Processing complete. All images have been cropped and saved.")
# Out:
# Processing complete. All images have been cropped and saved.

# %%
import os
import shutil

# Define folder paths and the split text file path
input_folder = 'IAM/formsI-Z'  # Folder containing .png images
split_text = "C:/Users/crosi/Downloads/splits/splits/validation.uttlist"  # Path to text file with filenames
output_folder = "IAM/aachen_validation_set"  # Output folder for matched .png files

# Ensure the output folder exists
if not os.path.exists(output_folder):
    os.makedirs(output_folder)

# Read the list of base filenames from the split text file (without extensions)
with open(split_text, 'r') as f:
    validation_files = set(line.strip() for line in f)  # Use a set for fast lookups

# Iterate over all files in the input folder
for filename in os.listdir(input_folder):
    if filename.endswith('.png'):  # Only consider .png files
        # Extract the base filename (without extension) from the input folder file
        base_filename = os.path.splitext(filename)[0]
        
        # Check if the base filename matches any in the validation file list
        if base_filename in validation_files:
            source_path = os.path.join(input_folder, filename)  # Full path to the .png file
            destination_path = os.path.join(output_folder, filename)  # Destination path
            
            # Copy the file to the output folder
            shutil.copy(source_path, destination_path)
            print(f"Copied {filename} to {output_folder}")
# Out:
# Copied m01-090.png to IAM/aachen_validation_set
# Copied m01-115.png to IAM/aachen_validation_set
# Copied m01-160.png to IAM/aachen_validation_set
# Copied m02-052.png to IAM/aachen_validation_set
# Copied m02-075.png to IAM/aachen_validation_set
# Copied m02-083.png to IAM/aachen_validation_set
# Copied m02-090.png to IAM/aachen_validation_set
# Copied m02-102.png to IAM/aachen_validation_set
# Copied m02-106.png to IAM/aachen_validation_set
# Copied m03-062.png to IAM/aachen_validation_set
# Copied m03-095.png to IAM/aachen_validation_set
# Copied m04-000.png to IAM/aachen_validation_set
# Copied m04-007.png to IAM/aachen_validation_set
# Copied m04-012.png to IAM/aachen_validation_set
# Copied m04-019.png to IAM/aachen_validation_set
# Copied m04-024.png to IAM/aachen_validation_set
# Copied m04-145.png to IAM/aachen_validation_set
# Copied m04-152.png to IAM/aachen_validation_set
# Copied m04-164.png to IAM/aachen_validation_set
# Copied m04-180.png to IAM/aachen_validation_set
# Copied m04-190.png to IAM/aachen_validation_set
# Copied m04-200.png to IAM/aachen_validation_set
# Copied m04-209.png to IAM/aachen_validation_set
# Copied m04-216.png to IAM/aachen_validation_set
# Copied m04-222.png to IAM/aachen_validation_set
# Copied m04-251.png to IAM/aachen_validation_set
# Copied m06-019.png to IAM/aachen_validation_set
# Copied n02-000.png to IAM/aachen_validation_set
# Copied n02-016.png to IAM/aachen_validation_set
# Copied n02-082a.png to IAM/aachen_validation_set
# Copied n02-098.png to IAM/aachen_validation_set
# Copied n03-079.png to IAM/aachen_validation_set
# Copied n03-082.png to IAM/aachen_validation_set
# Copied n03-091.png to IAM/aachen_validation_set
# Copied n04-015.png to IAM/aachen_validation_set
# Copied n04-022.png to IAM/aachen_validation_set
# Copied n04-031.png to IAM/aachen_validation_set
# Copied n04-039.png to IAM/aachen_validation_set
# Copied n04-044.png to IAM/aachen_validation_set
# Copied n04-171.png to IAM/aachen_validation_set
# Copied n04-183.png to IAM/aachen_validation_set
# Copied n04-190.png to IAM/aachen_validation_set
# Copied n04-195.png to IAM/aachen_validation_set
# Copied n06-148.png to IAM/aachen_validation_set
# Copied n06-156.png to IAM/aachen_validation_set
# Copied n06-163.png to IAM/aachen_validation_set
# Copied n06-169.png to IAM/aachen_validation_set
# Copied n06-175.png to IAM/aachen_validation_set
# Copied n06-182.png to IAM/aachen_validation_set
# Copied n06-186.png to IAM/aachen_validation_set
# Copied n06-194.png to IAM/aachen_validation_set
# Copied n06-201.png to IAM/aachen_validation_set
# Copied p02-017.png to IAM/aachen_validation_set
# Copied p02-121.png to IAM/aachen_validation_set
# Copied p02-127.png to IAM/aachen_validation_set
# Copied p02-131.png to IAM/aachen_validation_set
# Copied p02-155.png to IAM/aachen_validation_set
# Copied p03-004.png to IAM/aachen_validation_set
# Copied p03-009.png to IAM/aachen_validation_set
# Copied p03-057.png to IAM/aachen_validation_set
# Copied p03-069.png to IAM/aachen_validation_set
# Copied p03-087.png to IAM/aachen_validation_set
# Copied p03-096.png to IAM/aachen_validation_set
# Copied p03-103.png to IAM/aachen_validation_set
# Copied p03-112.png to IAM/aachen_validation_set
# Copied p03-121.png to IAM/aachen_validation_set
# Copied p03-135.png to IAM/aachen_validation_set
# Copied p03-142.png to IAM/aachen_validation_set
# Copied p03-151.png to IAM/aachen_validation_set
# Copied p03-158.png to IAM/aachen_validation_set
# Copied p03-185.png to IAM/aachen_validation_set

# %%
import os
from bs4 import BeautifulSoup

def extract_text_from_xml(xml_file_path, output_file_path):
    """
    Extract text from an XML file and save it to a text file, replacing XML entities.
    
    :param xml_file_path: Path to the XML file to read.
    :param output_file_path: Path to the text file to save the extracted text.
    """
    # Open and read the XML file
    with open(xml_file_path, 'r') as f:
        file_content = f.read()

    # Parse the XML file with BeautifulSoup
    soup = BeautifulSoup(file_content, 'xml')

    # Find the 'machine-printed-part' tag
    tag1 = soup.find("machine-printed-part")

    if tag1 is None:
        print(f"No 'machine-printed-part' tag found in {xml_file_path}.")
        return

    # Find all 'machine-printed-line' tags within 'tag1'
    tag2 = tag1.find_all("machine-print-line")

    with open(output_file_path, 'w') as outfile:
        # Write the text from each 'machine-print-line' tag to the file
        for line in tag2:
            text = line.get("text")
            if text:
                # Replace XML entities manually if they are not auto-decoded
                text = text.replace("&apos;", "'").replace("&quot;", '"').replace("&amp;quot;", '"')
                outfile.write(text + '\n')

def process_all_xml_files_in_directory(input_directory, output_directory):
    """
    Process all XML files in the specified directory and save the extracted text
    to the output directory.

    :param input_directory: Path to the directory containing XML files.
    :param output_directory: Path to the directory where text files will be saved.
    """
    # Ensure output directory exists
    os.makedirs(output_directory, exist_ok=True)

    # Iterate through all files in the input directory
    for filename in os.listdir(input_directory):
        if filename.endswith('.xml'):
            xml_file_path = os.path.join(input_directory, filename)
            output_file_path = os.path.join(output_directory, filename.replace('.xml', '.txt'))
            
            # Extract text and save to file
            extract_text_from_xml(xml_file_path, output_file_path)
            print(f"Processed {filename}")

# Example usage
input_directory = 'IAM/aachen_validation_txt'
output_directory = 'IAM/aachen_validation_txt'
process_all_xml_files_in_directory(input_directory, output_directory)
# Out:
# Processed c04-156.xml
# Processed c04-160.xml
# Processed c06-083.xml
# Processed d01-024.xml
# Processed d01-056.xml
# Processed d01-060.xml
# Processed d03-112.xml
# Processed d04-005.xml
# Processed d04-008.xml
# Processed d04-071.xml
# Processed d04-075.xml
# Processed d04-081.xml
# Processed d04-117.xml
# Processed d04-121.xml
# Processed d06-000.xml
# Processed d06-015.xml
# Processed d06-030.xml
# Processed d06-050.xml
# Processed d06-082.xml
# Processed d06-091.xml
# Processed e01-014.xml
# Processed e01-018.xml
# Processed e06-006.xml
# Processed e06-037.xml
# Processed e06-041.xml
# Processed f04-046.xml
# Processed f04-049.xml
# Processed f04-093.xml
# Processed f04-096.xml
# Processed f04-100.xml
# Processed f07-028b.xml
# Processed f07-032b.xml
# Processed f07-036.xml
# Processed f07-039b.xml
# Processed f07-042b.xml
# Processed f07-046b.xml
# Processed g01-083.xml
# Processed g03-016.xml
# Processed g03-058.xml
# Processed g04-036.xml
# Processed g04-039.xml
# Processed g04-055.xml
# Processed g04-060.xml
# Processed g04-063.xml
# Processed h01-004.xml
# Processed m01-090.xml
# Processed m01-115.xml
# Processed m01-160.xml
# Processed m02-052.xml
# Processed m02-075.xml
# Processed m02-083.xml
# Processed m02-090.xml
# Processed m02-102.xml
# Processed m02-106.xml
# Processed m03-062.xml
# Processed m03-095.xml
# Processed m04-000.xml
# Processed m04-007.xml
# Processed m04-012.xml
# Processed m04-019.xml
# Processed m04-024.xml
# Processed m04-145.xml
# Processed m04-152.xml
# Processed m04-164.xml
# Processed m04-180.xml
# Processed m04-190.xml
# Processed m04-200.xml
# Processed m04-209.xml
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 61
#      59 input_directory = 'IAM/aachen_validation_txt'
#      60 output_directory = 'IAM/aachen_validation_txt'
# ---> 61 process_all_xml_files_in_directory(input_directory, output_directory)
#
# Cell In[21], line 55, in process_all_xml_files_in_directory(input_directory, output_directory)
#      52 output_file_path = os.path.join(output_directory, filename.replace('.xml', '.txt'))
#      54 # Extract text and save to file
# ---> 55 extract_text_from_xml(xml_file_path, output_file_path)
#      56 print(f"Processed {filename}")
#
# Cell In[21], line 16, in extract_text_from_xml(xml_file_path, output_file_path)
#      13     file_content = f.read()
#      15 # Parse the XML file with BeautifulSoup
# ---> 16 soup = BeautifulSoup(file_content, 'xml')
#      18 # Find the 'machine-printed-part' tag
#      19 tag1 = soup.find("machine-printed-part")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\bs4\__init__.py:335, in BeautifulSoup.__init__(self, markup, features, builder, parse_only, from_encoding, exclude_encodings, element_classes, **kwargs)
#     333 self.builder.initialize_soup(self)
#     334 try:
# --> 335     self._feed()
#     336     success = True
#     337     break
#
# File ~\AppData\Roaming\Python\Python310\site-packages\bs4\__init__.py:478, in BeautifulSoup._feed(self)
#     475 # Convert the document to Unicode.
#     476 self.builder.reset()
# --> 478 self.builder.feed(self.markup)
#     479 # Close out any unfinished strings and close all the open tags.
#     480 self.endData()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\bs4\builder\_lxml.py:237, in LXMLTreeBuilderForXML.feed(self, markup)
#     235         data = markup.read(self.CHUNK_SIZE)
#     236         if len(data) != 0:
# --> 237             self.parser.feed(data)
#     238     self.parser.close()
#     239 except (UnicodeDecodeError, LookupError, etree.ParserError) as e:
#
# File src\\lxml\\parser.pxi:1331, in lxml.etree._FeedParser.feed()
#
# File src\\lxml\\parser.pxi:1451, in lxml.etree._FeedParser.feed()
#
# File src\\lxml\\parsertarget.pxi:161, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\\lxml\\parsertarget.pxi:156, in lxml.etree._TargetParserContext._handleParseResult()
#
# File src\\lxml\\etree.pyx:351, in lxml.etree._ExceptionContext._raise_if_stored()
#
# File src\\lxml\\saxparser.pxi:576, in lxml.etree._handleSaxData()
#
# File src\\lxml\\parsertarget.pxi:108, in lxml.etree._PythonSaxParserTarget._handleSaxData()
#
# File ~\AppData\Roaming\Python\Python310\site-packages\bs4\builder\_lxml.py:345, in LXMLTreeBuilderForXML.data(self, content)
#     342     self.soup.handle_data(data)
#     343     self.soup.endData(self.processing_instruction_class)
# --> 345 def data(self, content):
#     346     self.soup.handle_data(content)
#     348 def doctype(self, name, pubid, system):
#
# KeyboardInterrupt:

# %%
import os
import re

# Define input and output folders
input_folder = "transcriptions_IAM_llava"  # Folder containing the .txt files
output_folder = "transcriptions_IAM_llava"  # Folder to save the cleaned .txt files
os.makedirs(output_folder, exist_ok=True)


def clean_text(file_path, output_folder):
    # Get the file name without extension
    file_name = os.path.splitext(os.path.basename(file_path))[0]

    # Read the content of the file
    with open(file_path, "r", encoding="utf-8") as file:
        content = file.read()

    # Remove the text between [INST] and [/INST] using a regular expression
    cleaned_content = re.sub(r'\[INST\].*?\[/INST\]', '', content, flags=re.DOTALL)

    # Save the cleaned content to a new file
    output_file_path = os.path.join(output_folder, f"{file_name}.txt")
    with open(output_file_path, "w", encoding="utf-8") as output_file:
        output_file.write(cleaned_content)

    print(f"Processed {file_path}, cleaned version saved to {output_file_path}")

# Main function to iterate over all txt files in the input folder
def main():
    # Iterate through all .txt files in the input folder
    for txt_file in os.listdir(input_folder):
            
        if txt_file.endswith(".txt"):
            file_path = os.path.join(input_folder, txt_file)
            clean_text(file_path, output_folder)

if __name__ == "__main__":
    main()
# Out:
# Deleted transcriptions_IAM_llava\c04-160_cleaned.txt
# Deleted transcriptions_IAM_llava\c06-083_cleaned.txt
# Deleted transcriptions_IAM_llava\d01-024_cleaned.txt
# Deleted transcriptions_IAM_llava\d01-056_cleaned.txt
# Deleted transcriptions_IAM_llava\d01-060_cleaned.txt
# Deleted transcriptions_IAM_llava\d03-112_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-005_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-008_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-071_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-075_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-081_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-117_cleaned.txt
# Deleted transcriptions_IAM_llava\d04-121_cleaned.txt
# Deleted transcriptions_IAM_llava\d06-000_cleaned.txt
# Deleted transcriptions_IAM_llava\d06-015_cleaned.txt
# Deleted transcriptions_IAM_llava\d06-030_cleaned.txt
# Deleted transcriptions_IAM_llava\d06-050_cleaned.txt
# Deleted transcriptions_IAM_llava\d06-082_cleaned.txt
# Deleted transcriptions_IAM_llava\d06-091_cleaned.txt
# Deleted transcriptions_IAM_llava\e01-014_cleaned.txt
# Deleted transcriptions_IAM_llava\e01-018_cleaned.txt
# Deleted transcriptions_IAM_llava\e06-006_cleaned.txt
# Deleted transcriptions_IAM_llava\e06-037_cleaned.txt
# Deleted transcriptions_IAM_llava\e06-041_cleaned.txt
# Deleted transcriptions_IAM_llava\f04-046_cleaned.txt
# Deleted transcriptions_IAM_llava\f04-049_cleaned.txt
# Deleted transcriptions_IAM_llava\f04-093_cleaned.txt
# Deleted transcriptions_IAM_llava\f04-096_cleaned.txt
# Deleted transcriptions_IAM_llava\f04-100_cleaned.txt
# Deleted transcriptions_IAM_llava\f07-028b_cleaned.txt
# Deleted transcriptions_IAM_llava\f07-032b_cleaned.txt
# Deleted transcriptions_IAM_llava\f07-036_cleaned.txt
# Deleted transcriptions_IAM_llava\f07-039b_cleaned.txt
# Deleted transcriptions_IAM_llava\f07-042b_cleaned.txt
# Deleted transcriptions_IAM_llava\f07-046b_cleaned.txt
# Deleted transcriptions_IAM_llava\g01-083_cleaned.txt
# Deleted transcriptions_IAM_llava\g03-016_cleaned.txt
# Deleted transcriptions_IAM_llava\g03-058_cleaned.txt
# Deleted transcriptions_IAM_llava\g04-036_cleaned.txt
# Deleted transcriptions_IAM_llava\g04-039_cleaned.txt
# Deleted transcriptions_IAM_llava\g04-055_cleaned.txt
# Deleted transcriptions_IAM_llava\g04-060_cleaned.txt
# Deleted transcriptions_IAM_llava\g04-063_cleaned.txt
# Deleted transcriptions_IAM_llava\h01-004_cleaned.txt
# Deleted transcriptions_IAM_llava\m01-090_cleaned.txt
# Deleted transcriptions_IAM_llava\m01-115_cleaned.txt
# Deleted transcriptions_IAM_llava\m01-160_cleaned.txt
# Deleted transcriptions_IAM_llava\m02-052_cleaned.txt
# Deleted transcriptions_IAM_llava\m02-075_cleaned.txt
# Deleted transcriptions_IAM_llava\m02-083_cleaned.txt
# Deleted transcriptions_IAM_llava\m02-090_cleaned.txt
# Deleted transcriptions_IAM_llava\m02-102_cleaned.txt
# Deleted transcriptions_IAM_llava\m02-106_cleaned.txt
# Deleted transcriptions_IAM_llava\m03-062_cleaned.txt
# Deleted transcriptions_IAM_llava\m03-095_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-000_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-007_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-012_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-019_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-024_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-145_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-152_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-164_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-180_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-190_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-200_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-209_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-216_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-222_cleaned.txt
# Deleted transcriptions_IAM_llava\m04-251_cleaned.txt
# Deleted transcriptions_IAM_llava\m06-019_cleaned.txt
# Deleted transcriptions_IAM_llava\n02-000_cleaned.txt
# Deleted transcriptions_IAM_llava\n02-016_cleaned.txt
# Deleted transcriptions_IAM_llava\n02-082a_cleaned.txt
# Deleted transcriptions_IAM_llava\n02-098_cleaned.txt
# Deleted transcriptions_IAM_llava\n03-079_cleaned.txt
# Deleted transcriptions_IAM_llava\n03-082_cleaned.txt
# Deleted transcriptions_IAM_llava\n03-091_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-015_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-022_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-031_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-039_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-044_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-171_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-183_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-190_cleaned.txt
# Deleted transcriptions_IAM_llava\n04-195_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-148_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-156_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-163_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-169_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-175_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-182_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-186_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-194_cleaned.txt
# Deleted transcriptions_IAM_llava\n06-201_cleaned.txt
# Deleted transcriptions_IAM_llava\p02-017_cleaned.txt
# Deleted transcriptions_IAM_llava\p02-121_cleaned.txt
# Deleted transcriptions_IAM_llava\p02-127_cleaned.txt
# Deleted transcriptions_IAM_llava\p02-131_cleaned.txt
# Deleted transcriptions_IAM_llava\p02-155_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-004_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-009_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-057_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-069_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-087_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-096_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-103_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-112_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-121_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-135_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-142_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-151_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-158_cleaned.txt
# Deleted transcriptions_IAM_llava\p03-185_cleaned.txt
# Processed transcriptions_IAM_llava\c04-156.txt, cleaned version saved to transcriptions_IAM_llava\c04-156.txt
# Processed transcriptions_IAM_llava\c04-160.txt, cleaned version saved to transcriptions_IAM_llava\c04-160.txt
# Processed transcriptions_IAM_llava\c06-083.txt, cleaned version saved to transcriptions_IAM_llava\c06-083.txt
# Processed transcriptions_IAM_llava\d01-024.txt, cleaned version saved to transcriptions_IAM_llava\d01-024.txt
# Processed transcriptions_IAM_llava\d01-056.txt, cleaned version saved to transcriptions_IAM_llava\d01-056.txt
# Processed transcriptions_IAM_llava\d01-060.txt, cleaned version saved to transcriptions_IAM_llava\d01-060.txt
# Processed transcriptions_IAM_llava\d03-112.txt, cleaned version saved to transcriptions_IAM_llava\d03-112.txt
# Processed transcriptions_IAM_llava\d04-005.txt, cleaned version saved to transcriptions_IAM_llava\d04-005.txt
# Processed transcriptions_IAM_llava\d04-008.txt, cleaned version saved to transcriptions_IAM_llava\d04-008.txt
# Processed transcriptions_IAM_llava\d04-071.txt, cleaned version saved to transcriptions_IAM_llava\d04-071.txt
# Processed transcriptions_IAM_llava\d04-075.txt, cleaned version saved to transcriptions_IAM_llava\d04-075.txt
# Processed transcriptions_IAM_llava\d04-081.txt, cleaned version saved to transcriptions_IAM_llava\d04-081.txt
# Processed transcriptions_IAM_llava\d04-117.txt, cleaned version saved to transcriptions_IAM_llava\d04-117.txt
# Processed transcriptions_IAM_llava\d04-121.txt, cleaned version saved to transcriptions_IAM_llava\d04-121.txt
# Processed transcriptions_IAM_llava\d06-000.txt, cleaned version saved to transcriptions_IAM_llava\d06-000.txt
# Processed transcriptions_IAM_llava\d06-015.txt, cleaned version saved to transcriptions_IAM_llava\d06-015.txt
# Processed transcriptions_IAM_llava\d06-030.txt, cleaned version saved to transcriptions_IAM_llava\d06-030.txt
# Processed transcriptions_IAM_llava\d06-050.txt, cleaned version saved to transcriptions_IAM_llava\d06-050.txt
# Processed transcriptions_IAM_llava\d06-082.txt, cleaned version saved to transcriptions_IAM_llava\d06-082.txt
# Processed transcriptions_IAM_llava\d06-091.txt, cleaned version saved to transcriptions_IAM_llava\d06-091.txt
# Processed transcriptions_IAM_llava\e01-014.txt, cleaned version saved to transcriptions_IAM_llava\e01-014.txt
# Processed transcriptions_IAM_llava\e01-018.txt, cleaned version saved to transcriptions_IAM_llava\e01-018.txt
# Processed transcriptions_IAM_llava\e06-006.txt, cleaned version saved to transcriptions_IAM_llava\e06-006.txt
# Processed transcriptions_IAM_llava\e06-037.txt, cleaned version saved to transcriptions_IAM_llava\e06-037.txt
# Processed transcriptions_IAM_llava\e06-041.txt, cleaned version saved to transcriptions_IAM_llava\e06-041.txt
# Processed transcriptions_IAM_llava\f04-046.txt, cleaned version saved to transcriptions_IAM_llava\f04-046.txt
# Processed transcriptions_IAM_llava\f04-049.txt, cleaned version saved to transcriptions_IAM_llava\f04-049.txt
# Processed transcriptions_IAM_llava\f04-093.txt, cleaned version saved to transcriptions_IAM_llava\f04-093.txt
# Processed transcriptions_IAM_llava\f04-096.txt, cleaned version saved to transcriptions_IAM_llava\f04-096.txt
# Processed transcriptions_IAM_llava\f04-100.txt, cleaned version saved to transcriptions_IAM_llava\f04-100.txt
# Processed transcriptions_IAM_llava\f07-028b.txt, cleaned version saved to transcriptions_IAM_llava\f07-028b.txt
# Processed transcriptions_IAM_llava\f07-032b.txt, cleaned version saved to transcriptions_IAM_llava\f07-032b.txt
# Processed transcriptions_IAM_llava\f07-036.txt, cleaned version saved to transcriptions_IAM_llava\f07-036.txt
# Processed transcriptions_IAM_llava\f07-039b.txt, cleaned version saved to transcriptions_IAM_llava\f07-039b.txt
# Processed transcriptions_IAM_llava\f07-042b.txt, cleaned version saved to transcriptions_IAM_llava\f07-042b.txt
# Processed transcriptions_IAM_llava\f07-046b.txt, cleaned version saved to transcriptions_IAM_llava\f07-046b.txt
# Processed transcriptions_IAM_llava\g01-083.txt, cleaned version saved to transcriptions_IAM_llava\g01-083.txt
# Processed transcriptions_IAM_llava\g03-016.txt, cleaned version saved to transcriptions_IAM_llava\g03-016.txt
# Processed transcriptions_IAM_llava\g03-058.txt, cleaned version saved to transcriptions_IAM_llava\g03-058.txt
# Processed transcriptions_IAM_llava\g04-036.txt, cleaned version saved to transcriptions_IAM_llava\g04-036.txt
# Processed transcriptions_IAM_llava\g04-039.txt, cleaned version saved to transcriptions_IAM_llava\g04-039.txt
# Processed transcriptions_IAM_llava\g04-055.txt, cleaned version saved to transcriptions_IAM_llava\g04-055.txt
# Processed transcriptions_IAM_llava\g04-060.txt, cleaned version saved to transcriptions_IAM_llava\g04-060.txt
# Processed transcriptions_IAM_llava\g04-063.txt, cleaned version saved to transcriptions_IAM_llava\g04-063.txt
# Processed transcriptions_IAM_llava\h01-004.txt, cleaned version saved to transcriptions_IAM_llava\h01-004.txt
# Processed transcriptions_IAM_llava\m01-090.txt, cleaned version saved to transcriptions_IAM_llava\m01-090.txt
# Processed transcriptions_IAM_llava\m01-115.txt, cleaned version saved to transcriptions_IAM_llava\m01-115.txt
# Processed transcriptions_IAM_llava\m01-160.txt, cleaned version saved to transcriptions_IAM_llava\m01-160.txt
# Processed transcriptions_IAM_llava\m02-052.txt, cleaned version saved to transcriptions_IAM_llava\m02-052.txt
# Processed transcriptions_IAM_llava\m02-075.txt, cleaned version saved to transcriptions_IAM_llava\m02-075.txt
# Processed transcriptions_IAM_llava\m02-083.txt, cleaned version saved to transcriptions_IAM_llava\m02-083.txt
# Processed transcriptions_IAM_llava\m02-090.txt, cleaned version saved to transcriptions_IAM_llava\m02-090.txt
# Processed transcriptions_IAM_llava\m02-102.txt, cleaned version saved to transcriptions_IAM_llava\m02-102.txt
# Processed transcriptions_IAM_llava\m02-106.txt, cleaned version saved to transcriptions_IAM_llava\m02-106.txt
# Processed transcriptions_IAM_llava\m03-062.txt, cleaned version saved to transcriptions_IAM_llava\m03-062.txt
# Processed transcriptions_IAM_llava\m03-095.txt, cleaned version saved to transcriptions_IAM_llava\m03-095.txt
# Processed transcriptions_IAM_llava\m04-000.txt, cleaned version saved to transcriptions_IAM_llava\m04-000.txt
# Processed transcriptions_IAM_llava\m04-007.txt, cleaned version saved to transcriptions_IAM_llava\m04-007.txt
# Processed transcriptions_IAM_llava\m04-012.txt, cleaned version saved to transcriptions_IAM_llava\m04-012.txt
# Processed transcriptions_IAM_llava\m04-019.txt, cleaned version saved to transcriptions_IAM_llava\m04-019.txt
# Processed transcriptions_IAM_llava\m04-024.txt, cleaned version saved to transcriptions_IAM_llava\m04-024.txt
# Processed transcriptions_IAM_llava\m04-145.txt, cleaned version saved to transcriptions_IAM_llava\m04-145.txt
# Processed transcriptions_IAM_llava\m04-152.txt, cleaned version saved to transcriptions_IAM_llava\m04-152.txt
# Processed transcriptions_IAM_llava\m04-164.txt, cleaned version saved to transcriptions_IAM_llava\m04-164.txt
# Processed transcriptions_IAM_llava\m04-180.txt, cleaned version saved to transcriptions_IAM_llava\m04-180.txt
# Processed transcriptions_IAM_llava\m04-190.txt, cleaned version saved to transcriptions_IAM_llava\m04-190.txt
# Processed transcriptions_IAM_llava\m04-200.txt, cleaned version saved to transcriptions_IAM_llava\m04-200.txt
# Processed transcriptions_IAM_llava\m04-209.txt, cleaned version saved to transcriptions_IAM_llava\m04-209.txt
# Processed transcriptions_IAM_llava\m04-216.txt, cleaned version saved to transcriptions_IAM_llava\m04-216.txt
# Processed transcriptions_IAM_llava\m04-222.txt, cleaned version saved to transcriptions_IAM_llava\m04-222.txt
# Processed transcriptions_IAM_llava\m04-251.txt, cleaned version saved to transcriptions_IAM_llava\m04-251.txt
# Processed transcriptions_IAM_llava\m06-019.txt, cleaned version saved to transcriptions_IAM_llava\m06-019.txt
# Processed transcriptions_IAM_llava\n02-000.txt, cleaned version saved to transcriptions_IAM_llava\n02-000.txt
# Processed transcriptions_IAM_llava\n02-016.txt, cleaned version saved to transcriptions_IAM_llava\n02-016.txt
# Processed transcriptions_IAM_llava\n02-082a.txt, cleaned version saved to transcriptions_IAM_llava\n02-082a.txt
# Processed transcriptions_IAM_llava\n02-098.txt, cleaned version saved to transcriptions_IAM_llava\n02-098.txt
# Processed transcriptions_IAM_llava\n03-079.txt, cleaned version saved to transcriptions_IAM_llava\n03-079.txt
# Processed transcriptions_IAM_llava\n03-082.txt, cleaned version saved to transcriptions_IAM_llava\n03-082.txt
# Processed transcriptions_IAM_llava\n03-091.txt, cleaned version saved to transcriptions_IAM_llava\n03-091.txt
# Processed transcriptions_IAM_llava\n04-015.txt, cleaned version saved to transcriptions_IAM_llava\n04-015.txt
# Processed transcriptions_IAM_llava\n04-022.txt, cleaned version saved to transcriptions_IAM_llava\n04-022.txt
# Processed transcriptions_IAM_llava\n04-031.txt, cleaned version saved to transcriptions_IAM_llava\n04-031.txt
# Processed transcriptions_IAM_llava\n04-039.txt, cleaned version saved to transcriptions_IAM_llava\n04-039.txt
# Processed transcriptions_IAM_llava\n04-044.txt, cleaned version saved to transcriptions_IAM_llava\n04-044.txt
# Processed transcriptions_IAM_llava\n04-171.txt, cleaned version saved to transcriptions_IAM_llava\n04-171.txt
# Processed transcriptions_IAM_llava\n04-183.txt, cleaned version saved to transcriptions_IAM_llava\n04-183.txt
# Processed transcriptions_IAM_llava\n04-190.txt, cleaned version saved to transcriptions_IAM_llava\n04-190.txt
# Processed transcriptions_IAM_llava\n04-195.txt, cleaned version saved to transcriptions_IAM_llava\n04-195.txt
# Processed transcriptions_IAM_llava\n06-148.txt, cleaned version saved to transcriptions_IAM_llava\n06-148.txt
# Processed transcriptions_IAM_llava\n06-156.txt, cleaned version saved to transcriptions_IAM_llava\n06-156.txt
# Processed transcriptions_IAM_llava\n06-163.txt, cleaned version saved to transcriptions_IAM_llava\n06-163.txt
# Processed transcriptions_IAM_llava\n06-169.txt, cleaned version saved to transcriptions_IAM_llava\n06-169.txt
# Processed transcriptions_IAM_llava\n06-175.txt, cleaned version saved to transcriptions_IAM_llava\n06-175.txt
# Processed transcriptions_IAM_llava\n06-182.txt, cleaned version saved to transcriptions_IAM_llava\n06-182.txt
# Processed transcriptions_IAM_llava\n06-186.txt, cleaned version saved to transcriptions_IAM_llava\n06-186.txt
# Processed transcriptions_IAM_llava\n06-194.txt, cleaned version saved to transcriptions_IAM_llava\n06-194.txt
# Processed transcriptions_IAM_llava\n06-201.txt, cleaned version saved to transcriptions_IAM_llava\n06-201.txt
# Processed transcriptions_IAM_llava\p02-017.txt, cleaned version saved to transcriptions_IAM_llava\p02-017.txt
# Processed transcriptions_IAM_llava\p02-121.txt, cleaned version saved to transcriptions_IAM_llava\p02-121.txt
# Processed transcriptions_IAM_llava\p02-127.txt, cleaned version saved to transcriptions_IAM_llava\p02-127.txt
# Processed transcriptions_IAM_llava\p02-131.txt, cleaned version saved to transcriptions_IAM_llava\p02-131.txt
# Processed transcriptions_IAM_llava\p02-155.txt, cleaned version saved to transcriptions_IAM_llava\p02-155.txt
# Processed transcriptions_IAM_llava\p03-004.txt, cleaned version saved to transcriptions_IAM_llava\p03-004.txt
# Processed transcriptions_IAM_llava\p03-009.txt, cleaned version saved to transcriptions_IAM_llava\p03-009.txt
# Processed transcriptions_IAM_llava\p03-057.txt, cleaned version saved to transcriptions_IAM_llava\p03-057.txt
# Processed transcriptions_IAM_llava\p03-069.txt, cleaned version saved to transcriptions_IAM_llava\p03-069.txt
# Processed transcriptions_IAM_llava\p03-087.txt, cleaned version saved to transcriptions_IAM_llava\p03-087.txt
# Processed transcriptions_IAM_llava\p03-096.txt, cleaned version saved to transcriptions_IAM_llava\p03-096.txt
# Processed transcriptions_IAM_llava\p03-103.txt, cleaned version saved to transcriptions_IAM_llava\p03-103.txt
# Processed transcriptions_IAM_llava\p03-112.txt, cleaned version saved to transcriptions_IAM_llava\p03-112.txt
# Processed transcriptions_IAM_llava\p03-121.txt, cleaned version saved to transcriptions_IAM_llava\p03-121.txt
# Processed transcriptions_IAM_llava\p03-135.txt, cleaned version saved to transcriptions_IAM_llava\p03-135.txt
# Processed transcriptions_IAM_llava\p03-142.txt, cleaned version saved to transcriptions_IAM_llava\p03-142.txt
# Processed transcriptions_IAM_llava\p03-151.txt, cleaned version saved to transcriptions_IAM_llava\p03-151.txt
# Processed transcriptions_IAM_llava\p03-158.txt, cleaned version saved to transcriptions_IAM_llava\p03-158.txt
# Processed transcriptions_IAM_llava\p03-185.txt, cleaned version saved to transcriptions_IAM_llava\p03-185.txt
